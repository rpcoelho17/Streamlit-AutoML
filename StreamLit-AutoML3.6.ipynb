# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys; print(sys.version)
import os
dpath = os.getcwd()
dpath
# Out:
# 3.10.6 | packaged by conda-forge | (main, Oct 24 2022, 16:02:16) [MSC v.1916 64 bit (AMD64)]
# 'c:\\Users\\Luzia\\Documents\\pasta\\Arquivos\\Benchmarking'

# %%
# %pip install streamlit

# %%
# %pip show streamlit
# Out:
# Name: streamlitNote: you may need to restart the kernel to use updated packages.
#
# Version: 1.28.0
# Summary: A faster way to build and share data apps
# Home-page: https://streamlit.io
# Author: Snowflake Inc
# Author-email: hello@streamlit.io
# License: Apache License 2.0
# Location: c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages
# Requires: altair, blinker, cachetools, click, gitpython, importlib-metadata, numpy, packaging, pandas, pillow, protobuf, pyarrow, pydeck, python-dateutil, requests, rich, tenacity, toml, tornado, typing-extensions, tzlocal, validators, watchdog
# Required-by: streamlit-pandas-profiling

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (23.3)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020BBF502BC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020BBF502EC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020BBF503070>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020BBF503220>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020BBF5033D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pip/

# %%
# %pip install pycaret
#==2.3.10 -q
# Out:
# Collecting pycaret
#   Downloading pycaret-3.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (8.4.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (4.64.0)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (1.22.4)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (1.4.1)
# Requirement already satisfied: jinja2>=1.2 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (3.1.2)
# Collecting scipy~=1.10.1 (from pycaret)
#   Downloading scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 8.7 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from pycaret)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (1.1.2)
# Collecting pyod>=1.0.8 (from pycaret)
#   Downloading pyod-1.1.0.tar.gz (153 kB)
#      -------------------------------------- 153.4/153.4 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (2.5.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: numba>=0.55.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (0.56.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (5.9.1)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (5.4.0)
# Requirement already satisfied: cloudpickle in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (2.1.0)
# Collecting deprecation>=2.1.0 (from pycaret)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting xxhash (from pycaret)
#   Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (3.5.2)
# Collecting scikit-plot>=0.3.7 (from pycaret)
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting yellowbrick>=1.4 (from pycaret)
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      -------------------------------------- 282.6/282.6 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.0.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (0.2.1)
# Collecting schemdraw==0.15 (from pycaret)
#   Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#      ---------------------------------------- 106.8/106.8 kB ? eta 0:00:00
# Collecting plotly-resampler>=0.8.3.1 (from pycaret)
#   Downloading plotly_resampler-0.9.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (0.13.2)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 (from pycaret)
#   Downloading sktime-0.21.1-py3-none-any.whl.metadata (25 kB)
# Collecting tbats>=1.1.3 (from pycaret)
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.0/44.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\luzia\python\python310\lib\site-packages (from pycaret) (1.8.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\luzia\python\python310\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in c:\users\luzia\python\python310\lib\site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\luzia\python\python310\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: backcall in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.3)
# Requirement already satisfied: pickleshare in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.30)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (2.16.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (60.10.0)
# Requirement already satisfied: stack-data in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.3.0)
# Requirement already satisfied: traitlets>=5 in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (5.3.0)
# Requirement already satisfied: colorama in c:\users\luzia\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\luzia\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\luzia\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\luzia\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\luzia\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.1.1)
# Requirement already satisfied: wheel in c:\users\luzia\python\python310\lib\site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\luzia\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.9.1)
# Requirement already satisfied: jupyter-core in c:\users\luzia\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: fastjsonschema in c:\users\luzia\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\luzia\python\python310\lib\site-packages (from numba>=0.55.0->pycaret) (0.39.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\luzia\python\python310\lib\site-packages (from plotly>=5.0.0->pycaret) (8.2.3)
# Collecting dash<3.0.0,>=2.11.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading dash-2.14.0-py3-none-any.whl.metadata (11 kB)
# Collecting orjson<4.0.0,>=3.8.0 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading orjson-3.9.9-cp310-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 50.5/50.5 kB 2.5 MB/s eta 0:00:00
# Collecting trace-updater>=0.0.8 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
#      -------------------------------------- 185.2/185.2 kB 3.7 MB/s eta 0:00:00
# Collecting tsdownsample==0.1.2 (from plotly-resampler>=0.8.3.1->pycaret)
#   Downloading tsdownsample-0.1.2-cp310-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\luzia\python\python310\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: urllib3 in c:\users\luzia\python\python310\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: six in c:\users\luzia\python\python310\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2022.6.15)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\luzia\python\python310\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.13)
# Collecting scikit-base<0.6.0 (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret)
#   Downloading scikit_base-0.5.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.3.0)
# Collecting retrying (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret)
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in c:\users\luzia\python\python310\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.5)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\luzia\python\python310\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\luzia\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\luzia\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\luzia\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\luzia\python\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\luzia\python\python310\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\luzia\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\luzia\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.1)
# Requirement already satisfied: wcwidth in c:\users\luzia\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\luzia\python\python310\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in c:\users\luzia\python\python310\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (304)
# Requirement already satisfied: executing in c:\users\luzia\python\python310\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.9.1)
# Requirement already satisfied: asttokens in c:\users\luzia\python\python310\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.7)
# Requirement already satisfied: pure-eval in c:\users\luzia\python\python310\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\luzia\python\python310\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\luzia\python\python310\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.3)
# Requirement already satisfied: entrypoints in c:\users\luzia\python\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: argon2-cffi in c:\users\luzia\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\luzia\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\luzia\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\luzia\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\users\luzia\python\python310\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: lxml in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: bleach in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.6.6)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\luzia\python\python310\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.1.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\luzia\python\python310\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.0.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\luzia\python\python310\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\luzia\python\python310\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\luzia\python\python310\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\luzia\python\python310\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\luzia\python\python310\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Downloading pycaret-3.1.0-py3-none-any.whl (483 kB)
#    --------------------------------------- 483.9/483.9 kB 15.3 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    --------------------------------------- 302.2/302.2 kB 18.2 MB/s eta 0:00:00
# Downloading plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 73.4/73.4 kB 1.0 MB/s eta 0:00:00
# Downloading sktime-0.21.1-py3-none-any.whl (17.1 MB)
#    ---------------------------------------- 17.1/17.1 MB 5.3 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp310-cp310-win_amd64.whl (29 kB)
# Downloading dash-2.14.0-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 10.4/10.4 MB 10.9 MB/s eta 0:00:00
# Downloading orjson-3.9.9-cp310-none-win_amd64.whl (135 kB)
#    ---------------------------------------- 135.0/135.0 kB 2.7 MB/s eta 0:00:00
# Downloading scikit_base-0.5.2-py3-none-any.whl (118 kB)
#    ---------------------------------------- 119.0/119.0 kB 7.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.1.0-py3-none-any.whl size=185349 sha256=39327863e300e784b79f746d5b5361fbb47afc6a37389ce0e9d6a33fdf8a57ae
#   Stored in directory: c:\users\luzia\appdata\local\pip\cache\wheels\36\8e\e2\e932956b10b843eb6be9eefa70b5c1bee7b561be14c423b136
# Successfully built pyod
# Installing collected packages: trace-updater, xxhash, tsdownsample, scipy, scikit-base, schemdraw, retrying, orjson, joblib, ansi2html, deprecation, yellowbrick, sktime, scikit-plot, pyod, dash, plotly-resampler, tbats, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.1
#     Uninstalling scipy-1.8.1:
#       Successfully uninstalled scipy-1.8.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: sktime
#     Found existing installation: sktime 0.13.0
#     Uninstalling sktime-0.13.0:
#       Successfully uninstalled sktime-0.13.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.6.1
#     Uninstalling dash-2.6.1:
#       Successfully uninstalled dash-2.6.1
# Successfully installed ansi2html-1.8.0 dash-2.14.0 deprecation-2.1.0 joblib-1.3.2 orjson-3.9.9 plotly-resampler-0.9.1 pycaret-3.1.0 pyod-1.1.0 retrying-1.3.4 schemdraw-0.15 scikit-base-0.5.2 scikit-plot-0.3.7 scipy-1.10.1 sktime-0.21.1 tbats-1.1.3 trace-updater-0.0.9.1 tsdownsample-0.1.2 xxhash-3.4.1 yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.3.2 which is incompatible.

# %%
# %pip show pycaret
# Out:
# Name: pycaret
# Version: 3.1.0
# Summary: PyCaret - An open source, low-code machine learning library in Python.
# Home-page: https://github.com/pycaret/pycaret
# Author: Moez Ali
# Author-email: moez.ali@queensu.ca
# License: MIT
# Location: c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages
# Requires: category-encoders, cloudpickle, deprecation, imbalanced-learn, importlib-metadata, ipython, ipywidgets, jinja2, joblib, kaleido, lightgbm, markupsafe, matplotlib, nbformat, numba, numpy, pandas, plotly, plotly-resampler, pmdarima, psutil, pyod, requests, schemdraw, scikit-learn, scikit-plot, scipy, sktime, statsmodels, tbats, tqdm, xxhash, yellowbrick
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\luzia\python\python310\lib\site-packages (3.2.0)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#      -------------------------------------- 309.8/309.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (1.4.1)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (3.5.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: visions==0.7.4 in c:\users\luzia\python\python310\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (1.22.4)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (0.4.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (2.28.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (4.64.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\luzia\python\python310\lib\site-packages (from pandas-profiling) (1.8)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\luzia\python\python310\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\luzia\python\python310\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (2.5.1)
# Requirement already satisfied: imagehash in c:\users\luzia\python\python310\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\luzia\python\python310\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\luzia\python\python310\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luzia\python\python310\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2022.6.15)
# Requirement already satisfied: colorama in c:\users\luzia\python\python310\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.5)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\luzia\python\python310\lib\site-packages (from networkx>=2.4->visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (4.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\luzia\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\luzia\python\python310\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.3.0)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
# Successfully installed joblib-1.1.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: visions 0.7.4 does not provide the extra 'type-image-path'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pycaret 3.1.0 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.

# %%
# %pip install streamlit-pandas-profiling==0.1.3 -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: visions 0.7.4 does not provide the extra 'type-image-path'

# %%
# %pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\luzia\python\python310\lib\site-packages (2.7.1)
# Requirement already satisfied: dash-colorscales in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: dash-daq in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: Flask-Compress in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.12)
# Requirement already satisfied: future>=0.14.0 in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: pandas in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.4.1)
# Requirement already satisfied: squarify in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: strsimpy in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: lz4 in c:\users\luzia\python\python310\lib\site-packages (from dtale) (4.0.2)
# Requirement already satisfied: certifi in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2022.6.15)
# Requirement already satisfied: cycler in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: dash-bootstrap-components in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.2.1)
# Requirement already satisfied: flask-ngrok in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: dash>=2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.14.0)
# Requirement already satisfied: kaleido in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: matplotlib in c:\users\luzia\python\python310\lib\site-packages (from dtale) (3.5.2)
# Requirement already satisfied: seaborn in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: networkx in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.1.2)
# Requirement already satisfied: statsmodels in c:\users\luzia\python\python310\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: numpy in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.22.4)
# Requirement already satisfied: openpyxl in c:\users\luzia\python\python310\lib\site-packages (from dtale) (3.0.10)
# Requirement already satisfied: xarray in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2022.6.0)
# Requirement already satisfied: et-xmlfile in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dtale) (5.9.0)
# Requirement already satisfied: requests in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.28.1)
# Requirement already satisfied: Flask in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.2.2)
# Requirement already satisfied: itsdangerous in c:\users\luzia\python\python310\lib\site-packages (from dtale) (2.1.2)
# Requirement already satisfied: scipy in c:\users\luzia\python\python310\lib\site-packages (from dtale) (1.10.1)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (2.2.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (4.3.0)
# Requirement already satisfied: retrying in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (1.5.5)
# Requirement already satisfied: setuptools in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (60.10.0)
# Requirement already satisfied: importlib-metadata in c:\users\luzia\python\python310\lib\site-packages (from dash>=2.0.0->dtale) (6.8.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\luzia\python\python310\lib\site-packages (from Flask->dtale) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\luzia\python\python310\lib\site-packages (from Flask->dtale) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\luzia\python\python310\lib\site-packages (from plotly>=5.0.0->dtale) (8.2.3)
# Requirement already satisfied: brotli in c:\users\luzia\python\python310\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luzia\python\python310\lib\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: decorator<5,>=4.3 in c:\users\luzia\python\python310\lib\site-packages (from networkx->dtale) (4.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luzia\python\python310\lib\site-packages (from pandas->dtale) (2022.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luzia\python\python310\lib\site-packages (from requests->dtale) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzia\python\python310\lib\site-packages (from requests->dtale) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luzia\python\python310\lib\site-packages (from requests->dtale) (1.26.11)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\luzia\python\python310\lib\site-packages (from scikit-learn->dtale) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\luzia\python\python310\lib\site-packages (from scikit-learn->dtale) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\luzia\python\python310\lib\site-packages (from statsmodels->dtale) (0.5.2)
# Requirement already satisfied: colorama in c:\users\luzia\python\python310\lib\site-packages (from click>=8.0->Flask->dtale) (0.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luzia\python\python310\lib\site-packages (from Jinja2>=3.0->Flask->dtale) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\luzia\python\python310\lib\site-packages (from importlib-metadata->dash>=2.0.0->dtale) (3.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install dtale[streamlit]
# Out:
# Requirement already satisfied: dtale[streamlit] in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (3.7.0)
# Requirement already satisfied: dash-colorscales in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.0.4)
# Requirement already satisfied: dash-daq in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.5.0)
# Requirement already satisfied: Flask-Compress in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.14)
# Requirement already satisfied: future>=0.14.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.18.3)
# Requirement already satisfied: kaleido in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.2.1)
# Requirement already satisfied: missingno in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.5.2)
# Requirement already satisfied: pandas in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.5.3)
# Requirement already satisfied: squarify in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.4.3)
# Requirement already satisfied: strsimpy in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.2.1)
# Requirement already satisfied: six in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (4.12.2)
# Requirement already satisfied: certifi in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2023.7.22)
# Requirement already satisfied: flask-ngrok in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.0.25)
# Requirement already satisfied: lz4 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (4.3.2)
# Requirement already satisfied: cycler in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.12.1)
# Requirement already satisfied: dash-bootstrap-components<=1.3.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.3.1)
# Requirement already satisfied: networkx in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (3.2.1)
# Requirement already satisfied: scikit-learn in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.2.2)
# Requirement already satisfied: seaborn in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.12.2)
# Requirement already satisfied: statsmodels in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (0.14.0)
# Requirement already satisfied: numpy in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.23.5)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (3.1.2)
# Requirement already satisfied: xarray in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2023.10.1)
# Requirement already satisfied: dash in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.14.1)
# Requirement already satisfied: et-xmlfile in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.1.0)
# Requirement already satisfied: plotly in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (5.18.0)
# Requirement already satisfied: Flask<2.3 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.2.3)
# Requirement already satisfied: itsdangerous in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.1.2)
# Requirement already satisfied: requests in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.31.0)
# Requirement already satisfied: werkzeug<2.3 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (3.7.3)
# Requirement already satisfied: scipy in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.10.1)
# Requirement already satisfied: streamlit in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dtale[streamlit]) (1.28.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (4.8.0)
# Requirement already satisfied: retrying in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (1.3.4)
# Requirement already satisfied: ansi2html in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (1.5.8)
# Requirement already satisfied: setuptools in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (68.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from dash->dtale[streamlit]) (5.2.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from Flask<2.3->dtale[streamlit]) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from Flask<2.3->dtale[streamlit]) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from plotly->dtale[streamlit]) (8.2.3)
# Requirement already satisfied: packaging in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from plotly->dtale[streamlit]) (21.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from werkzeug<2.3->dtale[streamlit]) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from beautifulsoup4->dtale[streamlit]) (2.5)
# Requirement already satisfied: brotli in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from Flask-Compress->dtale[streamlit]) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from matplotlib->dtale[streamlit]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from pandas->dtale[streamlit]) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from requests->dtale[streamlit]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from requests->dtale[streamlit]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from requests->dtale[streamlit]) (1.26.18)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from scikit-learn->dtale[streamlit]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from scikit-learn->dtale[streamlit]) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from statsmodels->dtale[streamlit]) (0.5.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (5.1.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (5.3.2)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (4.25.0)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (6.0.1)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (13.6.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from streamlit->dtale[streamlit]) (3.0.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from altair<6,>=4.0->streamlit->dtale[streamlit]) (4.19.2)
# Requirement already satisfied: toolz in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from altair<6,>=4.0->streamlit->dtale[streamlit]) (0.12.0)
# Requirement already satisfied: colorama in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from click>=8.0->Flask<2.3->dtale[streamlit]) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->dtale[streamlit]) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from importlib-metadata->dash->dtale[streamlit]) (3.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from rich<14,>=10.14.0->streamlit->dtale[streamlit]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from rich<14,>=10.14.0->streamlit->dtale[streamlit]) (2.16.1)
# Requirement already satisfied: tzdata in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from tzlocal<6,>=1.1->streamlit->dtale[streamlit]) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->dtale[streamlit]) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->dtale[streamlit]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->dtale[streamlit]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->dtale[streamlit]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->dtale[streamlit]) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->dtale[streamlit]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip show dtale
# Out:
# Name: dtale
# Version: 3.7.0
# Summary: Web Client for Visualizing Pandas Objects
# Home-page: https://github.com/man-group/dtale
# Author: MAN Alpha Technology
# Author-email: ManAlphaTech@man.com
# License: LGPL
# Location: c:\users\luzia\anaconda3\envs\py3.10.6\lib\site-packages
# Requires: beautifulsoup4, certifi, cycler, dash, dash-bootstrap-components, dash-colorscales, dash-daq, et-xmlfile, Flask, Flask-Compress, flask-ngrok, future, itsdangerous, kaleido, lz4, matplotlib, missingno, networkx, numpy, openpyxl, pandas, plotly, requests, scikit-learn, scipy, seaborn, six, squarify, statsmodels, strsimpy, werkzeug, xarray, xlrd
# Required-by:

# %%
# !npm install localtunnel
# Out:
# 'npm' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
# %pip list
# Out:
# Package                    Version
# -------------------------- -----------
# adagio                     0.2.4
# aiofiles                   22.1.0
# aiosignal                  1.3.1
# aiosqlite                  0.19.0
# alembic                    1.12.1
# altair                     5.1.2
# analytics-python           1.4.post1
# annotated-types            0.6.0
# ansi2html                  1.8.0
# antlr4-python3-runtime     4.11.1
# anyio                      3.7.1
# appdirs                    1.4.4
# argon2-cffi                23.1.0
# argon2-cffi-bindings       21.2.0
# arrow                      1.3.0
# asttokens                  2.4.1
# attrs                      23.1.0
# Babel                      2.13.1
# backoff                    1.10.0
# beautifulsoup4             4.12.2
# bleach                     6.1.0
# blinker                    1.7.0
# blis                       0.7.11
# bokeh                      3.3.0
# boto3                      1.28.76
# botocore                   1.31.76
# Brotli                     1.1.0
# cachetools                 5.3.2
# catalogue                  2.0.10
# catboost                   1.2.2
# category-encoders          2.6.3
# certifi                    2023.7.22
# cffi                       1.16.0
# chardet                    5.2.0
# charset-normalizer         3.3.2
# click                      8.1.7
# cloudpathlib               0.16.0
# cloudpickle                2.2.1
# colorama                   0.4.6
# colorlog                   6.7.0
# colour                     0.1.5
# comm                       0.1.4
# confection                 0.1.3
# contourpy                  1.1.1
# cryptography               41.0.5
# cycler                     0.12.1
# cymem                      2.0.8
# Cython                     3.0.5
# daal                       2023.2.1
# daal4py                    2023.2.1
# dacite                     1.8.1
# dash                       2.14.1
# dash-auth                  2.0.0
# dash-bootstrap-components  1.3.1
# dash-colorscales           0.0.4
# dash-core-components       2.0.0
# dash-cytoscape             0.3.0
# dash-daq                   0.5.0
# dash-html-components       2.0.0
# dash-table                 5.0.0
# dash-testing-stub          0.0.2
# dask                       2023.7.0
# databricks-cli             0.18.0
# deap                       1.4.1
# debugpy                    1.8.0
# decorator                  5.1.1
# defusedxml                 0.7.1
# Deprecated                 1.2.14
# deprecation                2.1.0
# dill                       0.3.7
# distributed                2023.7.0
# docker                     6.1.3
# dtale                      3.7.0
# dtreeviz                   2.2.2
# entrypoints                0.4
# et-xmlfile                 1.1.0
# evidently                  0.2.8
# exceptiongroup             1.1.3
# executing                  2.0.1
# explainerdashboard         0.4.3
# fairlearn                  0.7.0
# fastai                     2.7.13
# fastapi                    0.104.1
# fastcore                   1.5.29
# fastdownload               0.0.7
# fastjsonschema             2.18.1
# fastprogress               1.0.3
# ffmpy                      0.3.1
# filelock                   3.13.1
# FLAML                      2.1.1
# Flask                      2.2.3
# Flask-Compress             1.14
# flask-ngrok                0.0.25
# flask-simplelogin          0.1.2
# Flask-WTF                  1.2.1
# fonttools                  4.43.1
# fqdn                       1.5.1
# frozenlist                 1.4.0
# fs                         2.4.16
# fsspec                     2023.10.0
# fugue                      0.8.6
# fugue-sql-antlr            0.1.8
# future                     0.18.3
# gevent                     23.9.1
# gitdb                      4.0.11
# GitPython                  3.1.40
# gradio                     3.50.2
# gradio_client              0.6.1
# graphviz                   0.20.1
# greenlet                   3.0.1
# h11                        0.14.0
# htmlmin                    0.1.12
# httpcore                   0.18.0
# httpx                      0.25.0
# huggingface-hub            0.18.0
# hyperopt                   0.2.7
# idna                       3.4
# ImageHash                  4.3.1
# imageio                    2.31.6
# imbalanced-learn           0.11.0
# importlib-metadata         5.2.0
# importlib-resources        6.1.0
# iniconfig                  2.0.0
# interpret                  0.4.4
# interpret-core             0.4.4
# ipykernel                  6.26.0
# ipython                    8.17.2
# ipython-genutils           0.2.0
# ipywidgets                 8.1.1
# isoduration                20.11.0
# itsdangerous               2.1.2
# jedi                       0.19.1
# Jinja2                     3.1.2
# jmespath                   1.0.1
# joblib                     1.3.2
# json5                      0.9.14
# jsonpointer                2.4
# jsonschema                 4.19.2
# jsonschema-specifications  2023.7.1
# jupyter_client             7.4.9
# jupyter_core               5.5.0
# jupyter-dash               0.4.2
# jupyter-events             0.8.0
# jupyter_server             2.9.1
# jupyter_server_fileid      0.9.0
# jupyter_server_terminals   0.4.4
# jupyter_server_ydoc        0.8.0
# jupyter-ydoc               0.2.5
# jupyterlab                 3.6.6
# jupyterlab-pygments        0.2.2
# jupyterlab_server          2.25.0
# jupyterlab-widgets         3.0.9
# kaleido                    0.2.1
# kiwisolver                 1.4.5
# kmodes                     0.12.2
# langcodes                  3.3.0
# lazy_loader                0.3
# lightgbm                   4.1.0
# lime                       0.2.0.1
# llvmlite                   0.41.1
# locket                     1.0.0
# lxml                       4.9.3
# lz4                        4.3.2
# m2cgen                     0.10.0
# Mako                       1.2.4
# markdown-it-py             3.0.0
# MarkupSafe                 2.1.3
# matplotlib                 3.7.3
# matplotlib-inline          0.1.6
# mdurl                      0.1.2
# missingno                  0.5.2
# mistune                    3.0.2
# mitosheet                  0.1.522
# mlflow                     1.30.1
# mlxtend                    0.23.0
# monotonic                  1.6
# moto                       4.2.7
# mpmath                     1.3.0
# msgpack                    1.0.7
# multimethod                1.10
# multiprocess               0.70.15
# murmurhash                 1.0.10
# nbclassic                  1.0.0
# nbclient                   0.8.0
# nbconvert                  7.10.0
# nbformat                   5.9.2
# nest-asyncio               1.5.8
# networkx                   3.2.1
# nltk                       3.8.1
# notebook                   6.5.6
# notebook_shim              0.2.3
# numba                      0.58.1
# numpy                      1.23.5
# oauthlib                   3.2.2
# openpyxl                   3.1.2
# optuna                     3.4.0
# orjson                     3.9.10
# outcome                    1.3.0.post0
# overrides                  7.4.0
# oyaml                      1.0
# packaging                  21.3
# pandas                     1.5.3
# pandas-profiling           3.6.6
# pandocfilters              1.5.0
# parso                      0.8.3
# partd                      1.4.1
# patsy                      0.5.3
# percy                      2.0.2
# phik                       0.12.3
# Pillow                     10.0.1
# pip                        23.3
# platformdirs               3.11.0
# plotly                     5.18.0
# plotly-resampler           0.9.1
# pluggy                     1.3.0
# pmdarima                   2.0.4
# preshed                    3.0.9
# prometheus-client          0.18.0
# prometheus-flask-exporter  0.23.0
# prompt-toolkit             3.0.39
# protobuf                   4.25.0
# psutil                     5.9.6
# pure-eval                  0.2.2
# py4j                       0.10.9.7
# pyaml                      23.9.7
# pyarrow                    6.0.1
# pycaret                    3.1.0
# pycparser                  2.21
# pydantic                   1.10.11
# pydantic_core              2.10.1
# pydeck                     0.8.1b0
# pydub                      0.25.1
# Pygments                   2.16.1
# PyJWT                      2.8.0
# pynndescent                0.5.10
# pyod                       1.1.1
# pyOpenSSL                  23.3.0
# pyparsing                  3.1.1
# PySocks                    1.7.1
# pytest                     7.4.3
# python-dateutil            2.8.2
# python-json-logger         2.0.7
# python-multipart           0.0.6
# pytz                       2022.7.1
# PyWavelets                 1.4.1
# pywin32                    306
# pywinpty                   2.0.12
# PyYAML                     6.0.1
# pyzmq                      24.0.1
# qpd                        0.4.4
# querystring-parser         1.2.4
# ray                        2.7.1
# referencing                0.30.2
# regex                      2023.10.3
# requests                   2.31.0
# responses                  0.23.3
# retrying                   1.3.4
# rfc3339-validator          0.1.4
# rfc3986-validator          0.1.1
# rich                       13.6.0
# rpds-py                    0.10.6
# s3transfer                 0.7.0
# SALib                      1.4.7
# schemdraw                  0.15
# scikit-base                0.5.2
# scikit-image               0.22.0
# scikit-learn               1.2.2
# scikit-learn-intelex       2023.2.1
# scikit-opt                 0.6.6
# scikit-optimize            0.9.0
# scikit-plot                0.3.7
# scipy                      1.10.1
# seaborn                    0.12.2
# selenium                   4.2.0
# semantic-version           2.10.0
# Send2Trash                 1.8.2
# setuptools                 68.0.0
# shap                       0.43.0
# six                        1.16.0
# skope-rules                1.0.1
# sktime                     0.21.1
# slicer                     0.0.7
# smart-open                 6.4.0
# smmap                      5.0.1
# sniffio                    1.3.0
# sortedcontainers           2.4.0
# soupsieve                  2.5
# spacy                      3.7.2
# spacy-legacy               3.0.12
# spacy-loggers              1.0.5
# SQLAlchemy                 1.4.50
# sqlglot                    19.0.2
# sqlparse                   0.4.4
# squarify                   0.4.3
# srsly                      2.4.8
# stack-data                 0.6.3
# starlette                  0.27.0
# statsforecast              1.5.0
# statsmodels                0.14.0
# stopit                     1.1.2
# streamlit                  1.28.0
# streamlit-pandas-profiling 0.1.3
# strsimpy                   0.2.1
# sympy                      1.12
# tabulate                   0.9.0
# tangled-up-in-unicode      0.2.0
# tbats                      1.1.3
# tbb                        2021.10.0
# tblib                      3.0.0
# tenacity                   8.2.3
# tensorboardX               2.6.2.2
# terminado                  0.17.1
# thinc                      8.2.1
# threadpoolctl              3.2.0
# tifffile                   2023.9.26
# tinycss2                   1.2.1
# toml                       0.10.2
# tomli                      2.0.1
# toolz                      0.12.0
# torch                      2.1.0
# torchvision                0.16.0
# tornado                    6.3.3
# TPOT                       0.12.1
# tqdm                       4.66.1
# trace-updater              0.0.9.1
# traitlets                  5.13.0
# treeinterpreter            0.2.3
# triad                      0.9.1
# trio                       0.22.2
# trio-websocket             0.11.1
# tsdownsample               0.1.2
# tune-sklearn               0.4.6
# typeguard                  4.1.5
# typer                      0.9.0
# types-python-dateutil      2.8.19.14
# types-PyYAML               6.0.12.12
# typing_extensions          4.8.0
# tzdata                     2023.3
# tzlocal                    5.2
# umap-learn                 0.5.4
# update-checker             0.18.0
# uri-template               1.3.0
# urllib3                    1.26.18
# urllib3-secure-extra       0.1.0
# uvicorn                    0.23.2
# validators                 0.22.0
# visions                    0.7.5
# waitress                   2.1.2
# wasabi                     1.1.2
# watchdog                   3.0.0
# wcwidth                    0.2.9
# weasel                     0.3.3
# webcolors                  1.13
# webencodings               0.5.1
# websocket-client           1.6.4
# websockets                 11.0.3
# Werkzeug                   2.2.3
# wheel                      0.41.2
# widgetsnbextension         4.0.9
# wordcloud                  1.9.2
# wrapt                      1.15.0
# wsproto                    1.2.0
# WTForms                    3.1.1
# xarray                     2023.10.1
# xgboost                    2.0.1
# xlrd                       2.0.1
# XlsxWriter                 3.1.3
# xmltodict                  0.13.0
# xxhash                     3.4.1
# xyzservices                2023.10.1
# y-py                       0.6.2
# ydata-profiling            4.6.0
# yellowbrick                1.5
# ypy-websocket              0.8.4
# zict                       3.0.0
# zipp                       3.17.0
# zope.event                 5.0
# zope.interface             6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python --version
# Out:
# Python 3.10.6

# %%
from dtale.app import get_instance

# %%
import dtale

# %%
from streamlit_pandas_profiling import st_profile_report

# %%
import pandas as pd

# %%
from hyperopt import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Luzia\Documents\pasta\Arquivos\Benchmarking\StreamLitTest3.6.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Luzia/Documents/pasta/Arquivos/Benchmarking/StreamLitTest3.6.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> from optuna import tpe
#
# ImportError: cannot import name 'tpe' from 'optuna' (c:\Users\Luzia\anaconda3\envs\py3.10.6\lib\site-packages\optuna\__init__.py)

# %%
# %%writefile app.py
from operator import index
import pandas as pd
import streamlit as st
from mitosheet.streamlit.v1 import spreadsheet
import dtale
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from pycaret.regression import *
from sklearn.model_selection import TimeSeriesSplit
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import bokeh.plotting as bp
from bokeh.models import RangeSlider, CrosshairTool, HoverTool
#from typing import Any, Dict, List, Tuple
from streamlit_pandas_profiling import st_profile_report
import os
dpath = os.getcwd()
from dtale.views import startup
from dtale.app import get_instance
import io
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_halving_search_cv



# def info_to_df(df):
#     buffer = io.StringIO()
#     df.info(buf=buffer)
#     s = buffer.getvalue()
#     lines = s.splitlines()[1:-1]
#     columns = lines[0].split()
#     data = [line.split() for line in lines[1:]]
#     info_df = pd.DataFrame(data, columns=columns)
#     return info_df



#if os.path.exists('/content/drive/MyDrive/Colab Notebooks/trainSS.csv'):
#    df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/trainSS.csv', index_col=None)

# Page config
st.set_page_config(page_title="Auto-EDA", layout="wide")

st.sidebar.title("Auto-EDA")
st.sidebar.title("1. Data")

# Load data
st.title("Upload Your Dataset")
if 'df' in st.session_state: # check if session state has new_table key
    df = (st.session_state.df)
else:
    file = st.file_uploader("Upload Your Dataset")
    if file:
        #df = pd.read_csv(file, index_col=None)
        st.session_state['df'] = st.cache_data(pd.read_csv)(file, index_col=None)
        df = st.session_state['df']
        st.session_state['TargetColStr'] = None
        #st.write(st.session_state["TargetColStr"], "TargetColStr defined as empty string.")

if 'df' in st.session_state:
   st.dataframe(st.session_state.df,height=350)
   st.dataframe(st.session_state.df.describe())
   cat_cols = st.session_state.df.select_dtypes(include=['object']).columns.tolist()
   st.write("Categorical columns: ",cat_cols)
   num_cols = st.session_state.df.select_dtypes(include=['number']).columns.tolist()
   st.write("Numerical columns: ",num_cols)
   st.write("df.shape:",df.shape)
   st.write("Variable Types: ",df.dtypes)
   Target_Col = st.selectbox('Select the target column:', st.session_state.df.columns, index=None)
   if st.session_state.get("TargetColStr") == None:
      st.session_state['TargetColStr']=Target_Col
   st.write("Target variable is: "+str(st.session_state['TargetColStr']))

      

################################## Data Cleaning Expander ###########################
DataClean=st.sidebar.expander("Data Cleaing:", expanded=True)
DataClean.write("Choose cleaning routines:")

######################### Plot Line graph ###############################
PlotSeries = DataClean.checkbox("Plot Target variable line graph:")
if PlotSeries:
    if st.session_state['TargetColStr'] is not None:
        df=st.session_state.df
        x_slider = st.slider("Choose the chart range:", min_value=df.index.min(), max_value=df.index.max(),value=(df.index.min(), df.index.max()), step=1)
        fig = bp.figure(tools="pan, box_zoom, save, reset", x_range=(x_slider[0], x_slider[1]), height = 300, width_policy="max")
        fig.add_tools(CrosshairTool())
        fig.add_tools(HoverTool(tooltips=[("y","@y"),("x", "@x")]))
        fig.line(x=df.index, y=df[st.session_state['TargetColStr']])
        st.bokeh_chart(fig)


######################### Adding Lag Columns ###############################
AddLagCols = DataClean.checkbox("Create Lag Columns for Target:")
if AddLagCols:
  if st.session_state.get('AddLagExecuted') == None:
    df=st.session_state.df
    if 'GrpByField' not in st.session_state:
      st.session_state.GrpByField=None
    st.selectbox('Is your data grouped by any field (Such as StoreID)?:', st.session_state.df.columns, index=None, key='GrpByField')
    NumLags = st.number_input("Enter the number of lag columns to create (hit ENTER to execute):", min_value=0, max_value=15, value=0)
    if NumLags >0:
        for i in range(1,NumLags+1):
          if st.session_state.GrpByField != None:
            df[f"Lag-{i}"] = df.groupby(st.session_state.GrpByField)[st.session_state["TargetColStr"]].shift(-i)
          else:
            df[f"Lag-{i}"] = df[st.session_state["TargetColStr"]].shift(-i)
        df=df.dropna(axis=0, subset=[f"Lag-{j}" for j in range(1,NumLags+1)])
        st.session_state.df = df
        st.write("Here is your dataframe with the added lag columns:")
        st.dataframe(st.session_state.df, height=205)
        st.session_state['AddLagExecuted'] = True
  else:
    st.write("Here is your dataframe with the added lag columns:")
    st.dataframe(st.session_state.df, height=205)
else:
  st.session_state['AddLagExecuted'] = None



######################### Treating Missing Values ###############################
MissingValues = DataClean.checkbox("Missing Value Analysis")
if MissingValues:
    def plot_missing_values(df):
        # calculate the number and percentage of missing values for each field
        total = df.shape[0]
        missing = df.isnull().sum()
        percent = missing / total * 100

        # create a bar chart that shows the percentage of missing values for each field
        fig, ax = plt.subplots(figsize=(10, 2)) # adjust figure size
        ax.bar(df.columns, percent)
        ax.set_ylabel('% Missing')
        ax.set_xticklabels(df.columns, rotation=90)
        ax.grid(axis='y', linestyle='--') #, which='major') # added which='major' to show only horizontal gridlines

        # display the chart using streamlit
        st.pyplot(fig)

        # create a table that shows the field names, the total number of records, the number of existing records, the number of missing values, and the percentage of missing values for each field
        table = pd.DataFrame({
            'Field': df.columns,
            'Total': total,
            'Existing': total - missing,
            'Missing': missing,
            'Percent': percent
        })
        table["Delete?"]=False
        return table
    df =st.session_state.df
    MVtable = plot_missing_values(df)
    # display the table using streamlit
    MVtable = st.data_editor(MVtable.set_index('Field'), use_container_width=True) # set the index to be the field column to avoid showing it twice
    Selected_Rows = MVtable[MVtable["Delete?"]==True].index.to_list()
    # create another table that shows only fields that have percentages above 50% missing
    HighMissing = MVtable[MVtable['Percent'] > 50]
    st.write("Fields with over 50% missing:")
    st.table(HighMissing)
    st.write("Fields marked for deletion:",Selected_Rows)

    # Display a Delete button below the data editor
    if st.button("Delete marked columns"):
        # Delete the columns in df that are in Selected_Rows
        df = df.drop(Selected_Rows, axis=1)
        st.session_state['df'] = df # store the new table in session state
        # Display a success message and the updated df
        st.success(f"Deleted {len(Selected_Rows)} columns from df:")
        st.dataframe(df.head(3))
        df.to_csv('df.csv', index=None)



############################### Data Clean - Auto-impute #############################
AutoImpute = DataClean.checkbox("Auto impute Values")
if AutoImpute:
  # Define Auto Impute function:
  def impute_column(df, col, target):
    # Check if the column has any missing values
    if df[col].isnull().any():
      # Get the percentage of missing values in the column
      percent = df[col].isnull().mean() * 100
      # If the percentage is more than 50, drop the column and return the dataframe
      if percent > 50:
        df.drop(col, axis=1, inplace=True)
        return pd.DataFrame(data=None)
      # Otherwise, proceed with the imputation process
      else:
        # Get the data type of the column
        dtype = df[col].dtype
        # If the column is numeric
        if dtype in ["int", "float"]:
          # Check if there is a strong correlation between the column and the target variable
          corr = df[[col, target]].corr().iloc[0, 1]
          st.write('Correlation between '+col+' and '+target+' is '+ str(corr))
          # If the correlation coefficient is above 0.5 or below -0.5, use random forest imputation
          if abs(corr) > 0.5:
            # Import the RandomForestRegressor or RandomForestClassifier class from scikit-learn
            from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
            imp_model = RandomForestRegressor()
            st.write("Correlation is greater than 0.5 -> Using Random Forest regressor")
            # Fit the model on the rows that have no missing values in the column, using all other columns as predictors
            imp_model.fit(df.dropna()[df.columns.drop(col)], df.dropna()[col])
            # Predict the missing values in the column using the fitted model and the other columns as inputs
            df.loc[df[col].isnull(), col] = imp_model.predict(df[df[col].isnull()][df.columns.drop(col)])
          else:
            # Get the distribution of the column
            skewness = df[col].skew()
            # If the column is normally distributed, use mean imputation
            if abs(skewness) < 0.5:
              st.write('Absolute Skewness in column '+col+' is '+ str(abs(skewness)) + ' < 0.5, imputing the mean')
              imp_mean = SimpleImputer(missing_values=np.nan, strategy="mean")
              df[col] = imp_mean.fit_transform(df[[col]])
            # If the column is skewed, use median imputation
            else:
              st.write('Absolute Skewness in column '+col+' is ' + str(abs(skewness)) + ' > 0.5, imputing the median')
              imp_median = SimpleImputer(missing_values=np.nan, strategy="median")
              df[col] = imp_median.fit_transform(df[[col]])

        # If the column is categorical
        elif dtype == "object" or dtype == "category":
          # Get the frequency of each category
          mode = df[col].mode()[0]
          count = df[col].value_counts()[mode]
          # If there is a clear mode, use mode imputation
          if count > df.shape[0] * 0.5:
            st.write("There is a clear mode in column: '+col+' -> Imputing the most frequent")
            imp_mode = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
            df[col] = imp_mode.fit_transform(df[[col]])
          # If there is no clear mode, use constant value imputation
          else:
            st.write('There is no clear mode in the Categorical column: '+col+' -> imputing "Unknown"')
            imp_constant = SimpleImputer(missing_values=np.nan, strategy="constant", fill_value="Unknown")
            df[col] = imp_constant.fit_transform(df[[col]])
        # If the column is neither numeric nor categorical, raise an error
        else:
          raise ValueError(f"Unsupported data type: {dtype}")
    else:
      st.write(col + " has no missing values.")
    return df[col]

  # Loop over all columns of df and impute values
  for col in df.columns.drop(st.session_state['TargetColStr']):
    # Call the impute_column function with each column name
    df_column = impute_column(df, col, st.session_state["TargetColStr"])
    if not df_column.empty:
      df[col] = df_column
    else:
      st.write(col+ " has over 50% missing velues column DROPPED ************************************<-----")




#################################### Decompose the date ##########################
# Define a function that decomposes the date into day, month, year, and other features
DateDecomp = DataClean.checkbox("Decompose Date field")
if DateDecomp:
  df=st.session_state.df
  Date_Col = st.selectbox('Select the Date column:', df.columns, index=None)
  if Date_Col != None:
    st.session_state['DateColStr']=Date_Col
    st.write("Date Column is: "+str(st.session_state['DateColStr']))
    def decompose_date(df, date_col,format_str="%d/%m/%Y"):
      # Convert the date column to datetime type
      df[date_col] = pd.to_datetime(df[date_col], format=format_str)
      # Extract the day, month, and year from the date column
      df['day'] = df[date_col].dt.day
      df['month'] = df[date_col].dt.month
      df['year'] = df[date_col].dt.year
      # Extract the day of week, week of year, and quarter from the date column
      df['dayofweek'] = df[date_col].dt.dayofweek
      df['weekofyear'] = df[date_col].dt.isocalendar().week
      df['quarter'] = df[date_col].dt.quarter
      # Extract the season from the month column (using meteorological seasons for Italy)
      seasons = {(12, 1, 2): 'winter', (3, 4, 5): 'spring', (6, 7, 8): 'summer', (9, 10, 11): 'autumn'}
      df['season'] = df['month'].apply(lambda x: next(v for k, v in seasons.items() if x in k))
      # Drop the original date column
      df = df.drop(date_col, axis=1)
      # Return the transformed data frame
      return df

    # Call the function with the date column name
    st.session_state.df = decompose_date(st.session_state.df, str(st.session_state['DateColStr']))
    #st.session_state['df'] = df # store the new table in session state
    st.dataframe(st.session_state.df.head(3))




############################### Target Encode Columns ################
TargetEnconde = DataClean.checkbox("Target Encode Columns")
if TargetEnconde:
  df=st.session_state.df
  features = st.multiselect('Select the Categorical Columns to target encode:', df.columns)
  def target_encode(df, target, feature):
    # Convert the feature to string type
    df[feature] = df[feature].astype(str)
    # Calculate the global mean of the target variable
    global_mean = df[target].mean()
    # Calculate the number of samples and the mean of the target variable for each category
    grouped = df.groupby(feature)[target].agg(["count", "mean"])
    # Define the smoothing parameter (you can change this value)
    m = 10
    # Calculate the weight for each category
    weight = 1 / (1 + np.exp(-(grouped["count"] - m) / m))
    # Calculate the smoothed mean for each category
    smoothed_mean = weight * grouped["mean"] + (1 - weight) * global_mean
    # Replace the feature with the smoothed mean
    df[feature] = df[feature].map(smoothed_mean)
    # Return the transformed data frame
    return df[feature]

  EncodeColumnBtn = st.button("Target Encode columns")
  if EncodeColumnBtn:
    df = st.session_state['df']
    # Loop over all columns of df and encodes columns
    for col in features:
      # Call the the function with each column name
      df_column = target_encode(df,str(st.session_state['TargetColStr']),col)
      if not df_column.empty:
        df[col] = df_column
    st.dataframe(df,height=350)



#################################### Data Clean - Mitosheet ##########################
MitosheetCB = DataClean.checkbox("Mitosheet")
if MitosheetCB:
  new_dfs, code = spreadsheet(df)
  #st.write(type(new_dfs))
  st.session_state['df'] = new_dfs.get("df1")
  df = st.session_state['df']
  st.code(code)
  st.dataframe(st.session_state['df'], height=206)



#################################### Data Clean - Dtale ##########################
DtaleCB = DataClean.checkbox("Dtale")
if DtaleCB:
    df=st.session_state['df']
    startup(data_id="1", data=df)
    curr_instance = get_instance("1")
    CSS = """
    <style>
    /* Set the padding for the sidebar content */
    div.sidebar-content {
      padding: 1rem !important;
    }
    /* Set the width and font size for the sidebar content */
    div.sidebar-content {
      width: 40rem !important;
      font-size: 10px;
    }
    </style>
    """

    html = f"""
    {CSS}
    <iframe src="/dtale/main/1" style="height: 400px;width: 100%"/>
    """
    st.markdown(html, unsafe_allow_html=True)
    # Display a button to update session state manually
    if st.button('Trasfer Dtale data to streamlit'):
        #df=curr_instance.data
        st.session_state['df'] = get_instance("1").data
        #st.session_state['df'] = df
        st.write("Transferring data to st.session_state['df']")
        #df = curr_instance.data
        st.dataframe(st.session_state['df'].head(6))




PdProfiling = DataClean.checkbox("Pandas Profiling")
if PdProfiling:
    st.title("Pandas Profiling:")
    profile_df = st.session_state['df'].profile_report()
    st_profile_report(profile_df)



################################## Feature Selection Expander ###########################
st.sidebar.title("2. Feature Selection:")
FeatSel=st.sidebar.expander("Choose Feature Selection Methods:", expanded=True)

################################## Calculate Correlations ######################################
CalcCorr = FeatSel.checkbox("Calculate Column Correlations with Target:")
if CalcCorr:
  df=st.session_state['df']
  # Calculate the correlation matrix
  corr_matrix = df.corr()
  # Get the correlation values for the target column
  target_corr = corr_matrix[st.session_state['TargetColStr']]
  st.write("Correlations with "+st.session_state['TargetColStr']+":")
  st.write(target_corr)




################################## Eliminate low Correlation Columns ###########################
DropLowCorr = FeatSel.checkbox("Eliminate Low Correlation Columns")
if DropLowCorr:
  # Define the function to drop columns with low correlation
  @st.cache_data
  def drop_low_corr(df, target, min_corr=0.5):
    corr_matrix = df.corr()
    target_corr = corr_matrix[target]
    st.write(target_corr)
    # Drop the columns that have correlation lower than min_corr
    df = df.drop(target_corr[target_corr < min_corr].index, axis=1)
    # Return the modified dataframe
    return df

  # Create a slider to select the minimum correlation value
  min_corr = st.slider("Select the minimum acceptable correlation", 0.0, 1.0, 0.5)

  # Create a button to call the function
  if st.button("Eliminate Numerical Columns w/ Low Correlation"):
    # Call the function with the selected min_corr value
    df = drop_low_corr(st.session_state['df'], st.session_state['TargetColStr'], min_corr)
    st.session_state['df']=df
    # Display the modified dataframe
    st.dataframe(st.session_state['df'])




################################## Corellation Plot ############################################
CorPlot = FeatSel.checkbox("Correlation Plot")
if CorPlot:
    df=st.session_state['df']
    st.write("df.shape:",df.shape)
    def corrdot(*args, **kwargs):
        corr_r = args[0].corr(args[1], 'pearson')
        corr_text = f"{corr_r:2.2f}".replace("0.", ".")
        ax = plt.gca()
        ax.set_axis_off()
        marker_size = abs(corr_r) * 10000
        ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
                  vmin=-1, vmax=1, transform=ax.transAxes)
        font_size = abs(corr_r) * 40 + 5
        ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                    ha='center', va='center', fontsize=font_size)

    sns.set(style='white', font_scale=1.6)
    g = sns.PairGrid(df[df.columns], aspect=1.4, diag_sharey=False)
    g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
    g.map_diag(sns.histplot, kde_kws={'color': 'black'})
    g.map_upper(corrdot)
    st.pyplot(g)



################################# Pycaret Feature Selection ##############################################
PyFeatSel = FeatSel.checkbox("Pycaret Feature Selection")
if PyFeatSel:
    if st.session_state.get('FeatSelExecuted') == None:
        df=st.session_state['df']
        st.write("df.shape:",df.shape)
        method = st.selectbox('Choose the feature selection method:',options = [' ','Univariate','Random Forest','Sequential']) 
        if method !=' ':
            tss=TimeSeriesSplit(n_splits=5)
            setup(data=df, target=st.session_state['TargetColStr'], feature_selection=True, 
                remove_multicollinearity=True, feature_selection_method=method,
                fold_strategy=tss, fold=5, data_split_shuffle=False, fold_shuffle=False, 
                #log_experiment=True, experiment_name='pycaret_regression',
                session_id=42)
            setup_df = pull()
            st.dataframe(setup_df)
            st.session_state['df']=get_config('X_transformed').join(get_config('y_transformed'))
            st.write("These are the selected features in the transformed df:")
            st.dataframe(st.session_state['df'], height=205)
            df=st.session_state['df']
            st.write("df.shape:",df.shape)
            st.session_state['FeatSelExecuted']=True
else:
    st.session_state['FeatSelExecuted']= None




st.sidebar.title("3. Model Development:")
################################## Model Dev Expander ###########################
ModelDev=st.sidebar.expander("Choose how you want to develop your model:", expanded=True)
PycaretDefault = ModelDev.checkbox("Pycaret Model Development")
if PycaretDefault:
  if st.session_state.get('ModelDevExecuted') == None:
    df=st.session_state['df']
    st.write("df.shape:",df.shape)
    tss=TimeSeriesSplit(n_splits=5)
    setup(data=df, target=st.session_state['TargetColStr'], feature_selection=False, 
            #preprocess=False, remove_multicollinearity=True,
            fold_strategy=tss, fold=5, data_split_shuffle=False, fold_shuffle=False, 
            #log_experiment=True, experiment_name='pycaret_regression',
            session_id=42)
    st.session_state.setup_df = pull()
    st.write("Model Setup:")
    st.dataframe(st.session_state.setup_df)
    df=get_config('X_transformed').join(get_config('y_transformed'))
    st.write("Target Variable: ",st.session_state['TargetColStr'])
    st.write("df Used:")
    st.dataframe(df, height=205)
    st.write("df.shape:",df.shape)
    Best = compare_models(sort='MAE')
    st.session_state.compare_df = pull()
    st.write("Model Leaderboard:")
    st.dataframe(st.session_state.compare_df)
    Model = create_model(Best)
    st.session_state['Model']=Model
    st.session_state.ModelOutput = pull()
    st.write("Best Model Class: ", type(Model))
    st.write("Model Output:")
    st.dataframe(st.session_state.ModelOutput)
    st.write("Model Parameters:")
    st.dataframe (pd.DataFrame.from_dict(Model.get_params(),orient='index', columns=['value']))
    Prediction = predict_model(Model, verbose=True)
    st.session_state.PredictionDF=pull()
    st.write("Prediction Scores:")
    st.dataframe(st.session_state.PredictionDF)
    st.session_state.df=df
 
    st.write("Model Pipeline:")
    img=plot_model(Model,plot='pipeline', display_format='streamlit',save=True)
    st.image(img)
    img=plot_model(Model,plot='error', display_format='streamlit',save=True)
    st.image(img, use_column_width=True)
    img=plot_model(Model,plot='feature_all', display_format='streamlit', save=True)
    st.image(img)
    img=plot_model(Model,plot='vc', display_format='streamlit',save=True)
    st.image(img)
    save_model(Model, 'best_model')
    st.session_state['ModelDevExecuted'] = True
  else:
    st.write("Model Setup:")
    st.dataframe(st.session_state.setup_df)
    st.write("Model Leaderboard:")
    st.dataframe(st.session_state.compare_df)
    st.write("Model Output:")
    st.dataframe(st.session_state.ModelOutput)
    st.write("Prediction Scores:")
    st.dataframe(st.session_state.PredictionDF)
else:
  st.session_state['ModelDevExecuted'] = None
        


TuneModel = ModelDev.checkbox("Fine tune model")
if TuneModel:
  if st.session_state.get('ModelTuningExecuted') == None:
    df=st.session_state['df']
    Model=st.session_state.Model
    if 'TuneType' not in st.session_state:
        st.session_state.TuneType = ' '
    st.selectbox('Select Tuning model:', options = [' ','Sklearn-Random Search'
                ,'Scikit-Optimize Bayesian','Optuna TPE'], index=None, key='TuneType')
    if st.session_state.TuneType != ' ':
        st.write("Starting optimization with "+st.session_state.TuneType+"...")
        if st.session_state.TuneType=='Sklearn-Random Search':
            TModel = tune_model(Model, optimize='MAE', n_iter=5)
        elif st.session_state.TuneType=='Scikit-Optimize Bayesian':
            TModel = tune_model(Model, optimize='MAE', n_iter=5, search_library='scikit-optimize', search_algorithm='bayesian')
        #elif st.session_state.TuneType=='Tune-Sklearn Bayesian':
        #   TModel = tune_model(Model, optimize='MAE', n_iter=5, search_library='tune-sklearn', search_algorithm='bayesian', verbose=True)
        elif st.session_state.TuneType=='Optuna TPE':
            TModel = tune_model(Model, optimize='MAE', n_iter=5, search_library='optuna', search_algorithm='tpe')

        st.session_state.Tuned_model = pull()
        st.write("Tuned Model with "+st.session_state.TuneType+".   Cross-Validation Results:")
        st.dataframe(st.session_state.Tuned_model)
        st.write(st.session_state.TuneType+" Tuned Model Parameters:")
        st.session_state.TModelParams = pd.DataFrame.from_dict(TModel.get_params(),orient='index', columns=['value'])
        st.dataframe (st.session_state.TModelParams)
        st.session_state.TPrediction = predict_model(TModel, verbose=True)
        st.session_state.TPredictionDF=pull()
        st.write("Prediction Scores with "+st.session_state.TuneType+":")
        st.dataframe(st.session_state.TPredictionDF)
        st.write("Model Pipeline:")
        img=plot_model(Model,plot='pipeline', display_format='streamlit',save=True)
        st.image(img)
        img=plot_model(Model,plot='error', display_format='streamlit',save=True)
        st.image(img, use_column_width=True)
        img=plot_model(Model,plot='feature_all', display_format='streamlit', save=True)
        st.image(img)
        img=plot_model(Model,plot='vc', display_format='streamlit',save=True)
        st.image(img)
        save_model(TModel, 'Tuned_model')
        st.session_state['ModelTuningExecuted'] = True
  else:
    st.write("Tuned Model with "+st.session_state.TuneType+".   Cross-Validation Results:")
    st.dataframe(st.session_state.Tuned_model)
    st.write(st.session_state.TuneType+" Tuned Model Parameters:")
    st.session_state.TModelParams = pd.DataFrame.from_dict(TModel.get_params(),orient='index', columns=['value'])
    st.dataframe (st.session_state.TModelParams)
    st.write("Prediction Scores with "+st.session_state.TuneType+":")
    st.dataframe(st.session_state.TPredictionDF)
else:
  st.session_state['ModelTuningExecuted'] = None

st.sidebar.title("4. File Input/Output:")
################################## SaveFile Expander ###########################
SaveFile=st.sidebar.expander("File Operations:", expanded=True)
@st.cache_data
def convert_df(df):
  return df.to_csv(index=None).encode('utf-8')

if 'df' in st.session_state:
  # Create an input box to enter the file name without extension
  file_name = SaveFile.text_input("Enter a file name and hit 'Enter' to be able to download the dataset (no extension needed):", " ")
  if file_name != " ":
    csv = convert_df(df)
    # Append .csv to the file name
    file_name = file_name + ".csv"
    # Create a download button with the file name as a parameter
    SaveFile.download_button("Dowload data as CSV",data=csv, file_name=file_name, mime='text/csv')

Reload = SaveFile.file_uploader("Reload Your Dataset")
if Reload:
    df = st.cache_data(pd.read_csv)(Reload, index_col=None)
    st.session_state['df'] = df
    st.dataframe(st.session_state['df'])


PrintDF=st.sidebar.button("Print df")
if PrintDF and ('df' in st.session_state):
  st.dataframe(st.session_state.df)


with st.sidebar:
    choice = st.radio("Navigation", ["Upload","Dtale","Profiling","Modelling", "Download"])
    st.info("This streamlit app can perform auto-EDA and auto-ML on regression analysis problems.")


if choice == "Modelling":
    chosen_target = st.selectbox('Choose the Target Column', df.columns)
    if st.button('Run Modelling'):
        setup(df, target=chosen_target)
        setup_df = pull()
        st.dataframe(setup_df)
        best_model = compare_models()
        compare_df = pull()
        st.dataframe(compare_df)
        save_model(best_model, 'best_model')

if choice == "Download":
    with open('best_model.pkl', 'rb') as f:
        st.download_button('Download Model', f, file_name="best_model.pkl")
# Out:
# Overwriting app.py

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 'wget' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
dtale-streamlit run app.py
#!dtale-streamlit run app.py & npx localtunnel --port 8501

# %%
# !conda env list

# %% [markdown]
# #**Tests:**

# %%
? str
# Out:
# Init signature:  str(self, /, *args, **kwargs)
# Docstring:
# str(object='') -> str
# str(bytes_or_buffer[, encoding[, errors]]) -> str
#
# Create a new string object from the given object. If encoding or
# errors is specified, then the object must expose a data buffer
# that will be decoded using the given encoding and error handler.
# Otherwise, returns the result of object.__str__() (if defined)
# or repr(object).
# encoding defaults to sys.getdefaultencoding().
# errors defaults to 'strict'.
# Type:           type
# Subclasses:     DeferredConfigString, _rstr, LSString, include, Keys, InputMode, ColorDepth, CompleteStyle, SortKey, FoldedCase, ...

# %%
df = pd.read_csv(dpath+'\\trainSSS.csv', index_col=None)

# %%
df.select_dtypes(include=['object']).columns.to_list()
# Out:
# ['Date', 'StoreType', 'AssortmentType', 'Events', 'Precipitationmm']

# %%
df.head()
# Out:
#    StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 0     1000  01/03/2016          0       1              0  Hyper Market
# 1     1000  02/03/2016          0       1              0  Hyper Market
# 2     1000  04/03/2016          0       1              0  Hyper Market
# 3     1000  05/03/2016          0       1              0  Hyper Market
# 4     1000  06/03/2016          0       0              0  Hyper Market
#
#   AssortmentType  NearestCompetitor  Region  NumberOfCustomers  ...  \
# 0        General                326       7                495  ...
# 1        General                326       7                608  ...
# 2        General                326       7                665  ...
# 3        General                326       7                630  ...
# 4        General                326       7                  0  ...
#
#    Mean_TemperatureC  Mean_VisibilityKm  Mean_Wind_SpeedKm_h  Min_Dew_PointC  \
# 0                  1               11.0                   16              -2
# 1                  3               13.0                   10              -2
# 2                  3               11.0                   10              -3
# 3                  3               15.0                   10              -6
# 4                  1               12.0                    5              -6
#
#    Min_Humidity Min_Sea_Level_PressurehPa  Min_TemperatureC  Min_VisibilitykM  \
# 0            70                      1029                 1               6.0
# 1            58                      1025                 1              10.0
# 2            55                      1023                 2               8.0
# 3            25                      1022                -1              10.0
# 4            48                      1022                -5               5.0
#
#    Precipitationmm  WindDirDegrees
# 0                0              23
# 1                0              56
# 2                0              22
# 3                0             108
# 4                0              46
#
# [5 rows x 36 columns]

# %%
from pycaret.regression import setup, get_config, create_model, pull, save_model, load_model, predict_model, tune_model, finalize_model, compare_models
from sklearn.model_selection import TimeSeriesSplit

# %%
tss=TimeSeriesSplit(n_splits=5)
setup(data=df, target=df['NumberOfSales'], feature_selection=True, remove_multicollinearity=True,
                      feature_selection_method='Univariate', fold_strategy=tss, log_experiment=True,
                      data_split_shuffle=False, fold_shuffle=False, 
                      experiment_name='pycaret_regression',session_id=42)
#remove_multicollinearity=True,
# Out:
# <style type="text/css">
# #T_5ef40_row11_col1, #T_5ef40_row17_col1, #T_5ef40_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5ef40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ef40_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5ef40_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ef40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ef40_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5ef40_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5ef40_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5ef40_row1_col1" class="data row1 col1" >NumberOfSales_y</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5ef40_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5ef40_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5ef40_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5ef40_row3_col1" class="data row3 col1" >(4919, 37)</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5ef40_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5ef40_row4_col1" class="data row4 col1" >(4919, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5ef40_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5ef40_row5_col1" class="data row5 col1" >(3443, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5ef40_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5ef40_row6_col1" class="data row6 col1" >(1476, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ef40_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_5ef40_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ef40_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_5ef40_row8_col1" class="data row8 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ef40_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_5ef40_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5ef40_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_5ef40_row10_col1" class="data row10 col1" >77.4%</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5ef40_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_5ef40_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5ef40_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_5ef40_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5ef40_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_5ef40_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5ef40_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_5ef40_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5ef40_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_5ef40_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5ef40_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_5ef40_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5ef40_row17_col0" class="data row17 col0" >Remove multicollinearity</td>
#       <td id="T_5ef40_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5ef40_row18_col0" class="data row18 col0" >Multicollinearity threshold</td>
#       <td id="T_5ef40_row18_col1" class="data row18 col1" >0.900000</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5ef40_row19_col0" class="data row19 col0" >Feature selection</td>
#       <td id="T_5ef40_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5ef40_row20_col0" class="data row20 col0" >Feature selection method</td>
#       <td id="T_5ef40_row20_col1" class="data row20 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5ef40_row21_col0" class="data row21 col0" >Feature selection estimator</td>
#       <td id="T_5ef40_row21_col1" class="data row21 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5ef40_row22_col0" class="data row22 col0" >Number of features selected</td>
#       <td id="T_5ef40_row22_col1" class="data row22 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_5ef40_row23_col0" class="data row23 col0" >Fold Generator</td>
#       <td id="T_5ef40_row23_col1" class="data row23 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_5ef40_row24_col0" class="data row24 col0" >Fold Number</td>
#       <td id="T_5ef40_row24_col1" class="data row24 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_5ef40_row25_col0" class="data row25 col0" >CPU Jobs</td>
#       <td id="T_5ef40_row25_col1" class="data row25 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_5ef40_row26_col0" class="data row26 col0" >Use GPU</td>
#       <td id="T_5ef40_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_5ef40_row27_col0" class="data row27 col0" >Log Experiment</td>
#       <td id="T_5ef40_row27_col1" class="data row27 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_5ef40_row28_col0" class="data row28 col0" >Experiment Name</td>
#       <td id="T_5ef40_row28_col1" class="data row28 col1" >pycaret_regression</td>
#     </tr>
#     <tr>
#       <th id="T_5ef40_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_5ef40_row29_col0" class="data row29 col0" >USI</td>
#       <td id="T_5ef40_row29_col1" class="data row29 col1" >02e2</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.columns
df.shape
# Out:
# (4919, 36)

# %%
pull()
# Out:
#                     Description             Value
# 0                    Session id                42
# 1                        Target   NumberOfSales_y
# 2                   Target type        Regression
# 3           Original data shape        (4919, 37)
# 4        Transformed data shape         (4919, 8)
# 5   Transformed train set shape         (3443, 8)
# 6    Transformed test set shape         (1476, 8)
# 7              Ordinal features                 1
# 8              Numeric features                31
# 9          Categorical features                 5
# 10     Rows with missing values             77.4%
# 11                   Preprocess              True
# 12              Imputation type            simple
# 13           Numeric imputation              mean
# 14       Categorical imputation              mode
# 15     Maximum one-hot encoding                25
# 16              Encoding method              None
# 17     Remove multicollinearity              True
# 18  Multicollinearity threshold               0.9
# 19            Feature selection              True
# 20     Feature selection method        Univariate
# 21  Feature selection estimator          lightgbm
# 22  Number of features selected               0.2
# 23               Fold Generator             KFold
# 24                  Fold Number                10
# 25                     CPU Jobs                -1
# 26                      Use GPU             False
# 27               Log Experiment             False
# 28              Experiment Name  reg-default-name
# 29                          USI              1300

# %%
get_config('X_transformed').join(get_config('y_transformed'))
#['_ml_usecase', 'X_train_transformed', 'y_test_transformed', 'target_param', 'y_train_transformed', 
# 'transform_target_param', 'seed', 'test_transformed', 'gpu_n_jobs_param', 'y_train', 'memory', 'n_jobs_param', 
# 'test', 'is_multiclass', 'X_train', 'dataset_transformed', 'exp_id', 'gpu_param', '_available_plots', 
# 'fold_shuffle_param', 'train_transformed', 'log_plots_param', 'pipeline', 'html_param', 'X_test', 'X', 
# 'variable_and_property_keys', 'USI', 'logging_param', 'idx', 'fold_groups_param', 'data', 'exp_name_log', 
# 'dataset', 'X_transformed', 'fold_generator', 'y_test', 'variables', 'y',
# 'X_test_transformed', 'train', 'y_transformed']
# Out:
#              Date  IsOpen  HasPromotions  StoreType_Super Market  \
# 0     4036.355967     1.0            0.0                     0.0
# 1     4213.673576     1.0            0.0                     0.0
# 2     4250.851898     1.0            0.0                     0.0
# 3     4190.760930     1.0            0.0                     0.0
# 4     3381.119971     0.0            0.0                     0.0
# ...           ...     ...            ...                     ...
# 4914  4201.894182     1.0            0.0                     0.0
# 4915  3440.853476     0.0            0.0                     0.0
# 4916  4071.918407     1.0            0.0                     0.0
# 4917  4138.565113     1.0            0.0                     0.0
# 4918  4153.893435     1.0            0.0                     0.0
#
#       NearestCompetitor  Region  Region_GDP  NumberOfSales_y
# 0                 326.0     7.0     17130.0             5676
# 1                 326.0     7.0     17130.0             8111
# 2                 326.0     7.0     17130.0             8300
# 3                 326.0     7.0     17130.0             7154
# 4                 326.0     7.0     17130.0                0
# ...                 ...     ...         ...              ...
# 4914            48278.0    10.0     11849.0             4379
# 4915            48278.0    10.0     11849.0                0
# 4916            48278.0    10.0     11849.0             5074
# 4917            48278.0    10.0     11849.0             5148
# 4918            48278.0    10.0     11849.0             4917
#
# [4919 rows x 8 columns]

# %%
Best = compare_models(sort='MAE')
Best
# Out:
# <style type="text/css">
# #T_54aa0 th {
#   text-align: left;
# }
# #T_54aa0_row0_col0, #T_54aa0_row0_col2, #T_54aa0_row0_col3, #T_54aa0_row0_col4, #T_54aa0_row0_col6, #T_54aa0_row1_col0, #T_54aa0_row1_col1, #T_54aa0_row1_col2, #T_54aa0_row1_col3, #T_54aa0_row1_col4, #T_54aa0_row1_col5, #T_54aa0_row1_col6, #T_54aa0_row2_col0, #T_54aa0_row2_col1, #T_54aa0_row2_col2, #T_54aa0_row2_col3, #T_54aa0_row2_col4, #T_54aa0_row2_col5, #T_54aa0_row2_col6, #T_54aa0_row3_col0, #T_54aa0_row3_col1, #T_54aa0_row3_col2, #T_54aa0_row3_col5, #T_54aa0_row4_col0, #T_54aa0_row4_col1, #T_54aa0_row4_col3, #T_54aa0_row4_col5, #T_54aa0_row5_col0, #T_54aa0_row5_col1, #T_54aa0_row5_col2, #T_54aa0_row5_col3, #T_54aa0_row5_col4, #T_54aa0_row5_col5, #T_54aa0_row5_col6, #T_54aa0_row6_col0, #T_54aa0_row6_col1, #T_54aa0_row6_col2, #T_54aa0_row6_col3, #T_54aa0_row6_col4, #T_54aa0_row6_col5, #T_54aa0_row6_col6, #T_54aa0_row7_col0, #T_54aa0_row7_col1, #T_54aa0_row7_col2, #T_54aa0_row7_col3, #T_54aa0_row7_col4, #T_54aa0_row7_col5, #T_54aa0_row7_col6, #T_54aa0_row8_col0, #T_54aa0_row8_col1, #T_54aa0_row8_col2, #T_54aa0_row8_col3, #T_54aa0_row8_col4, #T_54aa0_row8_col5, #T_54aa0_row8_col6, #T_54aa0_row9_col0, #T_54aa0_row9_col1, #T_54aa0_row9_col2, #T_54aa0_row9_col3, #T_54aa0_row9_col4, #T_54aa0_row9_col5, #T_54aa0_row9_col6, #T_54aa0_row10_col0, #T_54aa0_row10_col1, #T_54aa0_row10_col2, #T_54aa0_row10_col3, #T_54aa0_row10_col4, #T_54aa0_row10_col5, #T_54aa0_row10_col6, #T_54aa0_row11_col0, #T_54aa0_row11_col1, #T_54aa0_row11_col2, #T_54aa0_row11_col3, #T_54aa0_row11_col4, #T_54aa0_row11_col5, #T_54aa0_row11_col6, #T_54aa0_row12_col0, #T_54aa0_row12_col1, #T_54aa0_row12_col2, #T_54aa0_row12_col3, #T_54aa0_row12_col4, #T_54aa0_row12_col5, #T_54aa0_row12_col6, #T_54aa0_row13_col0, #T_54aa0_row13_col1, #T_54aa0_row13_col2, #T_54aa0_row13_col3, #T_54aa0_row13_col4, #T_54aa0_row13_col5, #T_54aa0_row13_col6, #T_54aa0_row14_col0, #T_54aa0_row14_col1, #T_54aa0_row14_col2, #T_54aa0_row14_col3, #T_54aa0_row14_col4, #T_54aa0_row14_col5, #T_54aa0_row14_col6, #T_54aa0_row15_col0, #T_54aa0_row15_col1, #T_54aa0_row15_col2, #T_54aa0_row15_col3, #T_54aa0_row15_col4, #T_54aa0_row15_col5, #T_54aa0_row15_col6, #T_54aa0_row16_col0, #T_54aa0_row16_col1, #T_54aa0_row16_col2, #T_54aa0_row16_col3, #T_54aa0_row16_col4, #T_54aa0_row16_col5, #T_54aa0_row16_col6, #T_54aa0_row17_col0, #T_54aa0_row17_col1, #T_54aa0_row17_col2, #T_54aa0_row17_col3, #T_54aa0_row17_col4, #T_54aa0_row17_col5, #T_54aa0_row17_col6, #T_54aa0_row18_col0, #T_54aa0_row18_col1, #T_54aa0_row18_col2, #T_54aa0_row18_col3, #T_54aa0_row18_col4, #T_54aa0_row18_col5, #T_54aa0_row18_col6, #T_54aa0_row19_col0, #T_54aa0_row19_col1, #T_54aa0_row19_col2, #T_54aa0_row19_col3, #T_54aa0_row19_col4, #T_54aa0_row19_col5, #T_54aa0_row19_col6 {
#   text-align: left;
# }
# #T_54aa0_row0_col1, #T_54aa0_row0_col5, #T_54aa0_row3_col3, #T_54aa0_row3_col4, #T_54aa0_row3_col6, #T_54aa0_row4_col2, #T_54aa0_row4_col4, #T_54aa0_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_54aa0_row0_col7, #T_54aa0_row1_col7, #T_54aa0_row2_col7, #T_54aa0_row3_col7, #T_54aa0_row4_col7, #T_54aa0_row5_col7, #T_54aa0_row6_col7, #T_54aa0_row7_col7, #T_54aa0_row8_col7, #T_54aa0_row9_col7, #T_54aa0_row10_col7, #T_54aa0_row11_col7, #T_54aa0_row12_col7, #T_54aa0_row13_col7, #T_54aa0_row14_col7, #T_54aa0_row15_col7, #T_54aa0_row16_col7, #T_54aa0_row18_col7, #T_54aa0_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_54aa0_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_54aa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54aa0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_54aa0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_54aa0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_54aa0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_54aa0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_54aa0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_54aa0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_54aa0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54aa0_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_54aa0_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_54aa0_row0_col1" class="data row0 col1" >1087.0746</td>
#       <td id="T_54aa0_row0_col2" class="data row0 col2" >4638858.2400</td>
#       <td id="T_54aa0_row0_col3" class="data row0 col3" >1414.6248</td>
#       <td id="T_54aa0_row0_col4" class="data row0 col4" >0.3623</td>
#       <td id="T_54aa0_row0_col5" class="data row0 col5" >0.8535</td>
#       <td id="T_54aa0_row0_col6" class="data row0 col6" >0.3542</td>
#       <td id="T_54aa0_row0_col7" class="data row0 col7" >1.0160</td>
#     </tr>
#     <tr>
#       <th id="T_54aa0_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_54aa0_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_54aa0_row1_col1" class="data row1 col1" >1116.8228</td>
#       <td id="T_54aa0_row1_col2" class="data row1 col2" >4630635.7951</td>
#       <td id="T_54aa0_row1_col3" class="data row1 col3" >1430.6214</td>
#       <td id="T_54aa0_row1_col4" class="data row1 col4" >0.3535</td>
#       <td id="T_54aa0_row1_col5" class="data row1 col5" >0.8852</td>
#       <td id="T_54aa0_row1_col6" class="data row1 col6" >0.3649</td>
#       <td id="T_54aa0_row1_col7" class="data row1 col7" >0.9180</td>
#     </tr>
#     <tr>
#       <th id="T_54aa0_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_54aa0_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_54aa0_row2_col1" class="data row2 col1" >1118.8518</td>
#       <td id="T_54aa0_row2_col2" class="data row2 col2" >4717926.2821</td>
#       <td id="T_54aa0_row2_col3" class="data row2 col3" >1438.7238</td>
#       <td id="T_54aa0_row2_col4" class="data row2 col4" >0.3492</td>
#       <td id="T_54aa0_row2_col5" class="data row2 col5" >1.4504</td>
#       <td id="T_54aa0_row2_col6" class="data row2 col6" >0.3508</td>
#       <td id="T_54aa0_row2_col7" class="data row2 col7" >0.9260</td>
#     </tr>
#     <tr>
#       <th id="T_54aa0_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_54aa0_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_54aa0_row3_col1" class="data row3 col1" >1128.0548</td>
#       <td id="T_54aa0_row3_col2" class="data row3 col2" >4178485.7553</td>
#       <td id="T_54aa0_row3_col3" class="data row3 col3" >1381.8876</td>
#       <td id="T_54aa0_row3_col4" class="data row3 col4" >0.4106</td>
#       <td id="T_54aa0_row3_col5" class="data row3 col5" >2.1058</td>
#       <td id="T_54aa0_row3_col6" class="data row3 col6" >0.3296</td>
#       <td id="T_54aa0_row3_col7" class="data row3 col7" >0.3320</td>
#     </tr>
#     <tr>
#       <th id="T_54aa0_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_54aa0_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_54aa0_row4_col1" class="data row4 col1" >1128.0914</td>
#       <td id="T_54aa0_row4_col2" class="data row4 col2" >4178385.1025</td>
#       <td id="T_54aa0_row4_col3" class="data row4 col3" >1381.9189</td>
#       <td id="T_54aa0_row4_col4" class="data row4 col4" >0.4106</td>
#       <td id="T_54aa0_row4_col5" class="data row4 col5" >2.1267</td>
#       <td id="T_54aa0_row4_col6" class="data row4 col6" >0.3296</td>
#       <td id="T_54aa0_row4_col7" class="data row4 col7" >0.4620</td>
#     </tr>
#     <tr>
#       <th id="T_54aa0_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_54aa0_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_54aa0_row5_col1" class="data row5 col1" >1132.8846</td>
#       <td id="T_54aa0_row5_col2" class="data row5 col2" >4190610.6
# ExtraTreesRegressor(n_jobs=-1, random_state=42)

# %%
pull()
# Out:
#                                     Model           MAE           MSE  \
# et                  Extra Trees Regressor  1.087075e+03  4.638858e+06
# rf                Random Forest Regressor  1.116823e+03  4.630636e+06
# lightgbm  Light Gradient Boosting Machine  1.118852e+03  4.717926e+06
# llar         Lasso Least Angle Regression  1.128055e+03  4.178486e+06
# lasso                    Lasso Regression  1.128091e+03  4.178385e+06
# ridge                    Ridge Regression  1.132885e+03  4.190611e+06
# lr                      Linear Regression  1.134397e+03  4.204911e+06
# gbr           Gradient Boosting Regressor  1.135229e+03  4.482249e+06
# xgboost         Extreme Gradient Boosting  1.153338e+03  4.963867e+06
# catboost               CatBoost Regressor  1.184867e+03  4.771681e+06
# huber                     Huber Regressor  1.216765e+03  4.766117e+06
# en                            Elastic Net  1.228954e+03  4.548730e+06
# ada                    AdaBoost Regressor  1.254790e+03  4.895295e+06
# br                         Bayesian Ridge  1.262874e+03  4.872294e+06
# knn                 K Neighbors Regressor  1.283172e+03  5.155902e+06
# dt                Decision Tree Regressor  1.283438e+03  6.135920e+06
# omp           Orthogonal Matching Pursuit  1.284263e+03  4.824249e+06
# par          Passive Aggressive Regressor  1.440721e+03  5.859382e+06
# dummy                     Dummy Regressor  2.138145e+03  7.997373e+06
# lar                Least Angle Regression  4.114878e+15  4.410074e+32
#
#                   RMSE            R2   RMSLE          MAPE  TT (Sec)
# et        1.414625e+03  3.623000e-01  0.8535  3.542000e-01     1.016
# rf        1.430621e+03  3.535000e-01  0.8852  3.649000e-01     0.918
# lightgbm  1.438724e+03  3.492000e-01  1.4504  3.508000e-01     0.926
# llar      1.381888e+03  4.106000e-01  2.1058  3.296000e-01     0.332
# lasso     1.381919e+03  4.106000e-01  2.1267  3.296000e-01     0.462
# ridge     1.392159e+03  4.065000e-01  2.1058  3.303000e-01     0.406
# lr        1.392644e+03  4.050000e-01  2.1082  3.309000e-01     6.778
# gbr       1.416862e+03  3.718000e-01  1.6795  3.552000e-01     0.736
# xgboost   1.491289e+03  3.120000e-01  1.4652  3.718000e-01     0.574
# catboost  1.472783e+03  3.328000e-01  1.8831  3.592000e-01     2.348
# huber     1.473067e+03  3.269000e-01  2.0703  3.502000e-01     0.486
# en        1.521507e+03  3.331000e-01  2.1410  3.306000e-01     0.580
# ada       1.619842e+03  2.928000e-01  2.0956  3.664000e-01     0.640
# br        1.549758e+03  2.939000e-01  2.1721  3.389000e-01     0.400
# knn       1.597643e+03  2.563000e-01  1.5931  3.594000e-01     0.386
# dt        1.670540e+03  1.368000e-01  1.0209  4.248000e-01     0.300
# omp       1.517755e+03  3.087000e-01  2.0899  3.438000e-01     0.298
# par       1.781868e+03  1.098000e-01  2.2278  3.827000e-01     0.270
# dummy     2.721761e+03 -3.829000e-01  3.8225  4.076000e-01     0.604
# lar       9.391564e+15 -9.484842e+25  4.5631  8.063058e+11     0.346

# %%
#Model = create_model('et')
Model = create_model(Best)
Model
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=42)

# %%
Model = tune_model(Model)
# Out:
# <style type="text/css">
# #T_06f6a_row5_col0, #T_06f6a_row5_col1, #T_06f6a_row5_col2, #T_06f6a_row5_col3, #T_06f6a_row5_col4, #T_06f6a_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_06f6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06f6a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_06f6a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_06f6a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_06f6a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_06f6a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_06f6a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06f6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06f6a_row0_col0" class="data row0 col0" >3540.3343</td>
#       <td id="T_06f6a_row0_col1" class="data row0 col1" >16322935.6646</td>
#       <td id="T_06f6a_row0_col2" class="data row0 col2" >4040.1653</td>
#       <td id="T_06f6a_row0_col3" class="data row0 col3" >-1.1265</td>
#       <td id="T_06f6a_row0_col4" class="data row0 col4" >3.7999</td>
#       <td id="T_06f6a_row0_col5" class="data row0 col5" >1.2250</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06f6a_row1_col0" class="data row1 col0" >827.5068</td>
#       <td id="T_06f6a_row1_col1" class="data row1 col1" >1745892.1068</td>
#       <td id="T_06f6a_row1_col2" class="data row1 col2" >1321.3221</td>
#       <td id="T_06f6a_row1_col3" class="data row1 col3" >0.7013</td>
#       <td id="T_06f6a_row1_col4" class="data row1 col4" >2.7711</td>
#       <td id="T_06f6a_row1_col5" class="data row1 col5" >0.2142</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06f6a_row2_col0" class="data row2 col0" >606.3489</td>
#       <td id="T_06f6a_row2_col1" class="data row2 col1" >805973.4387</td>
#       <td id="T_06f6a_row2_col2" class="data row2 col2" >897.7602</td>
#       <td id="T_06f6a_row2_col3" class="data row2 col3" >0.8267</td>
#       <td id="T_06f6a_row2_col4" class="data row2 col4" >1.1958</td>
#       <td id="T_06f6a_row2_col5" class="data row2 col5" >0.1499</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06f6a_row3_col0" class="data row3 col0" >448.3943</td>
#       <td id="T_06f6a_row3_col1" class="data row3 col1" >446070.1943</td>
#       <td id="T_06f6a_row3_col2" class="data row3 col2" >667.8849</td>
#       <td id="T_06f6a_row3_col3" class="data row3 col3" >0.9249</td>
#       <td id="T_06f6a_row3_col4" class="data row3 col4" >2.1163</td>
#       <td id="T_06f6a_row3_col5" class="data row3 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06f6a_row4_col0" class="data row4 col0" >406.2026</td>
#       <td id="T_06f6a_row4_col1" class="data row4 col1" >275907.6856</td>
#       <td id="T_06f6a_row4_col2" class="data row4 col2" >525.2692</td>
#       <td id="T_06f6a_row4_col3" class="data row4 col3" >0.9115</td>
#       <td id="T_06f6a_row4_col4" class="data row4 col4" >0.8630</td>
#       <td id="T_06f6a_row4_col5" class="data row4 col5" >0.1233</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_06f6a_row5_col0" class="data row5 col0" >1165.7574</td>
#       <td id="T_06f6a_row5_col1" class="data row5 col1" >3919355.8180</td>
#       <td id="T_06f6a_row5_col2" class="data row5 col2" >1490.4803</td>
#       <td id="T_06f6a_row5_col3" class="data row5 col3" >0.4476</td>
#       <td id="T_06f6a_row5_col4" class="data row5 col4" >2.1492</td>
#       <td id="T_06f6a_row5_col5" class="data row5 col5" >0.3592</td>
#     </tr>
#     <tr>
#       <th id="T_06f6a_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_06f6a_row6_col0" class="data row6 col0" >1196.4531</td>
#       <td id="T_06f6a_row6_col1" class="data row6 col1" >6222609.0134</td>
#       <td id="T_06f6a_row6_col2" class="data row6 col2" >1303.0058</td>
#       <td id="T_06f6a_row6_col3" class="data row6 col3" >0.7911</td>
#       <td id="T_06f6a_row6_col4" class="data row6 col4" >1.0655</td>
#       <td id="T_06f6a_row6_col5" class="data row6 col5" >0.4350</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
print(type(Model))
pd.DataFrame.from_dict(Model.get_params(),orient='index', columns=['value'])
# Out:
# <class 'sklearn.ensemble._forest.ExtraTreesRegressor'>
#                                   value
# bootstrap                         False
# ccp_alpha                           0.0
# criterion                 squared_error
# max_depth                            11
# max_features                       log2
# max_leaf_nodes                     None
# max_samples                        None
# min_impurity_decrease            0.0001
# min_samples_leaf                      3
# min_samples_split                     7
# min_weight_fraction_leaf            0.0
# n_estimators                         30
# n_jobs                               -1
# oob_score                         False
# random_state                         42
# verbose                               0
# warm_start                        False

# %%
type(Model)
# Out:
# sklearn.ensemble._forest.ExtraTreesRegressor

# %%
predict_model(Model, verbose=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c3c02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3c02_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c3c02_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c3c02_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c3c02_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c3c02_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c3c02_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c3c02_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3c02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3c02_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_c3c02_row0_col1" class="data row0 col1" >1175.7739</td>
#       <td id="T_c3c02_row0_col2" class="data row0 col2" >2448174.0114</td>
#       <td id="T_c3c02_row0_col3" class="data row0 col3" >1564.6642</td>
#       <td id="T_c3c02_row0_col4" class="data row0 col4" >0.6769</td>
#       <td id="T_c3c02_row0_col5" class="data row0 col5" >1.4986</td>
#       <td id="T_c3c02_row0_col6" class="data row0 col6" >0.2581</td>
#     </tr>
#   </tbody>
# </table>
#       StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 3443     1004  11/02/2018          0       0              0  Hyper Market
# 3444     1004  12/02/2018          0       1              0  Hyper Market
# 3445     1004  13/02/2018          0       1              0  Hyper Market
# 3446     1004  14/02/2018          0       1              0  Hyper Market
# 3447     1004  15/02/2018          0       1              0  Hyper Market
# ...       ...         ...        ...     ...            ...           ...
# 4914     1006  24/02/2018          0       1              0  Hyper Market
# 4915     1006  25/02/2018          0       0              0  Hyper Market
# 4916     1006  26/02/2018          0       1              0  Hyper Market
# 4917     1006  27/02/2018          0       1              0  Hyper Market
# 4918     1006  28/02/2018          0       1              0  Hyper Market
#
#                 AssortmentType  NearestCompetitor  Region  NumberOfCustomers  \
# 3443                   General              11805       2                  0
# 3444                   General              11805       2                180
# 3445                   General              11805       2                187
# 3446                   General              11805       2                179
# 3447                   General              11805       2                173
# ...                        ...                ...     ...                ...
# 4914  With Non-Food Department              48278      10                327
# 4915  With Non-Food Department              48278      10                  0
# 4916  With Non-Food Department              48278      10                410
# 4917  With Non-Food Department              48278      10                382
# 4918  With Non-Food Department              48278      10                391
#
#       ...  Mean_Wind_SpeedKm_h  Min_Dew_PointC  Min_Humidity  \
# 3443  ...                   23              -9            59
# 3444  ...                   26              -9            59
# 3445  ...                   13              -5            70
# 3446  ...                    5              -6            93
# 3447  ...                   10              -2            93
# ...   ...                  ...             ...           ...
# 4914  ...                   14               1            79
# 4915  ...                   13              -2            52
# 4916  ...                   14              -3            54
# 4917  ...                   14               0            59
# 4918  ...                   11              -1            51
#
#       Min_Sea_Level_PressurehPa  Min_TemperatureC Min_VisibilitykM  \
# 3443                       1019                -7              0.0
# 3444                       1025                -4              5.0
# 3445                       1028                -5             10.0
# 3446                       1025                -5              0.0
# 3447                       1023                -2              0.0
# ...                         ...               ...              ...
# 4914                        990                 2              3.0
# 4915                       1001                 1              9.0
# 4916                        992                 1              2.0
# 4917                        996                 2              6.0
# 4918                       1010                 1              5.0
#
#       Precipitationmm  WindDirDegrees  NumberOfSales_y  prediction_label
# 3443                0             282                0          0.000000
# 3444                0             255             3841       3740.435001
# 3445                0             281             3449       3612.078279
# 3446                0              94             3635       3560.561395
# 3447                0             115             3723       3667.208882
# ...               ...             ...              ...               ...
# 4914             0,51             224             4379       4415.064818
# 4915                0             223                0          0.000000
# 4916             1,02             194             5074       3992.497560
# 4917             1,02             215             5148       4206.276421
# 4918             0,25             211             4917       4275.767515
#
# [1476 rows x 38 columns]

# %%
Model=tune_model(Model)
# Out:
# <style type="text/css">
# #T_72dd6_row5_col0, #T_72dd6_row5_col1, #T_72dd6_row5_col2, #T_72dd6_row5_col3, #T_72dd6_row5_col4, #T_72dd6_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_72dd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72dd6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72dd6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72dd6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72dd6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72dd6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_72dd6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72dd6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72dd6_row0_col0" class="data row0 col0" >3540.3343</td>
#       <td id="T_72dd6_row0_col1" class="data row0 col1" >16322935.6646</td>
#       <td id="T_72dd6_row0_col2" class="data row0 col2" >4040.1653</td>
#       <td id="T_72dd6_row0_col3" class="data row0 col3" >-1.1265</td>
#       <td id="T_72dd6_row0_col4" class="data row0 col4" >3.7999</td>
#       <td id="T_72dd6_row0_col5" class="data row0 col5" >1.2250</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72dd6_row1_col0" class="data row1 col0" >827.5068</td>
#       <td id="T_72dd6_row1_col1" class="data row1 col1" >1745892.1068</td>
#       <td id="T_72dd6_row1_col2" class="data row1 col2" >1321.3221</td>
#       <td id="T_72dd6_row1_col3" class="data row1 col3" >0.7013</td>
#       <td id="T_72dd6_row1_col4" class="data row1 col4" >2.7711</td>
#       <td id="T_72dd6_row1_col5" class="data row1 col5" >0.2142</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72dd6_row2_col0" class="data row2 col0" >606.3489</td>
#       <td id="T_72dd6_row2_col1" class="data row2 col1" >805973.4387</td>
#       <td id="T_72dd6_row2_col2" class="data row2 col2" >897.7602</td>
#       <td id="T_72dd6_row2_col3" class="data row2 col3" >0.8267</td>
#       <td id="T_72dd6_row2_col4" class="data row2 col4" >1.1958</td>
#       <td id="T_72dd6_row2_col5" class="data row2 col5" >0.1499</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72dd6_row3_col0" class="data row3 col0" >448.3943</td>
#       <td id="T_72dd6_row3_col1" class="data row3 col1" >446070.1943</td>
#       <td id="T_72dd6_row3_col2" class="data row3 col2" >667.8849</td>
#       <td id="T_72dd6_row3_col3" class="data row3 col3" >0.9249</td>
#       <td id="T_72dd6_row3_col4" class="data row3 col4" >2.1163</td>
#       <td id="T_72dd6_row3_col5" class="data row3 col5" >0.0836</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_72dd6_row4_col0" class="data row4 col0" >406.2026</td>
#       <td id="T_72dd6_row4_col1" class="data row4 col1" >275907.6856</td>
#       <td id="T_72dd6_row4_col2" class="data row4 col2" >525.2692</td>
#       <td id="T_72dd6_row4_col3" class="data row4 col3" >0.9115</td>
#       <td id="T_72dd6_row4_col4" class="data row4 col4" >0.8630</td>
#       <td id="T_72dd6_row4_col5" class="data row4 col5" >0.1233</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_72dd6_row5_col0" class="data row5 col0" >1165.7574</td>
#       <td id="T_72dd6_row5_col1" class="data row5 col1" >3919355.8180</td>
#       <td id="T_72dd6_row5_col2" class="data row5 col2" >1490.4803</td>
#       <td id="T_72dd6_row5_col3" class="data row5 col3" >0.4476</td>
#       <td id="T_72dd6_row5_col4" class="data row5 col4" >2.1492</td>
#       <td id="T_72dd6_row5_col5" class="data row5 col5" >0.3592</td>
#     </tr>
#     <tr>
#       <th id="T_72dd6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_72dd6_row6_col0" class="data row6 col0" >1196.4531</td>
#       <td id="T_72dd6_row6_col1" class="data row6 col1" >6222609.0134</td>
#       <td id="T_72dd6_row6_col2" class="data row6 col2" >1303.0058</td>
#       <td id="T_72dd6_row6_col3" class="data row6 col3" >0.7911</td>
#       <td id="T_72dd6_row6_col4" class="data row6 col4" >1.0655</td>
#       <td id="T_72dd6_row6_col5" class="data row6 col5" >0.4350</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
tuned_result = predict_model(Model)
tuned_result
# Out:
# <style type="text/css">
# </style>
# <table id="T_94e8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94e8f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_94e8f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_94e8f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_94e8f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_94e8f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_94e8f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_94e8f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94e8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94e8f_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_94e8f_row0_col1" class="data row0 col1" >1175.7739</td>
#       <td id="T_94e8f_row0_col2" class="data row0 col2" >2448174.0114</td>
#       <td id="T_94e8f_row0_col3" class="data row0 col3" >1564.6642</td>
#       <td id="T_94e8f_row0_col4" class="data row0 col4" >0.6769</td>
#       <td id="T_94e8f_row0_col5" class="data row0 col5" >1.4986</td>
#       <td id="T_94e8f_row0_col6" class="data row0 col6" >0.2581</td>
#     </tr>
#   </tbody>
# </table>
#       StoreID        Date  IsHoliday  IsOpen  HasPromotions     StoreType  \
# 3443     1004  11/02/2018          0       0              0  Hyper Market
# 3444     1004  12/02/2018          0       1              0  Hyper Market
# 3445     1004  13/02/2018          0       1              0  Hyper Market
# 3446     1004  14/02/2018          0       1              0  Hyper Market
# 3447     1004  15/02/2018          0       1              0  Hyper Market
# ...       ...         ...        ...     ...            ...           ...
# 4914     1006  24/02/2018          0       1              0  Hyper Market
# 4915     1006  25/02/2018          0       0              0  Hyper Market
# 4916     1006  26/02/2018          0       1              0  Hyper Market
# 4917     1006  27/02/2018          0       1              0  Hyper Market
# 4918     1006  28/02/2018          0       1              0  Hyper Market
#
#                 AssortmentType  NearestCompetitor  Region  NumberOfCustomers  \
# 3443                   General              11805       2                  0
# 3444                   General              11805       2                180
# 3445                   General              11805       2                187
# 3446                   General              11805       2                179
# 3447                   General              11805       2                173
# ...                        ...                ...     ...                ...
# 4914  With Non-Food Department              48278      10                327
# 4915  With Non-Food Department              48278      10                  0
# 4916  With Non-Food Department              48278      10                410
# 4917  With Non-Food Department              48278      10                382
# 4918  With Non-Food Department              48278      10                391
#
#       ...  Mean_Wind_SpeedKm_h  Min_Dew_PointC  Min_Humidity  \
# 3443  ...                   23              -9            59
# 3444  ...                   26              -9            59
# 3445  ...                   13              -5            70
# 3446  ...                    5              -6            93
# 3447  ...                   10              -2            93
# ...   ...                  ...             ...           ...
# 4914  ...                   14               1            79
# 4915  ...                   13              -2            52
# 4916  ...                   14              -3            54
# 4917  ...                   14               0            59
# 4918  ...                   11              -1            51
#
#       Min_Sea_Level_PressurehPa  Min_TemperatureC Min_VisibilitykM  \
# 3443                       1019                -7              0.0
# 3444                       1025                -4              5.0
# 3445                       1028                -5             10.0
# 3446                       1025                -5              0.0
# 3447                       1023                -2              0.0
# ...                         ...               ...              ...
# 4914                        990                 2              3.0
# 4915                       1001                 1              9.0
# 4916                        992                 1              2.0
# 4917                        996                 2              6.0
# 4918                       1010                 1              5.0
#
#       Precipitationmm  WindDirDegrees  NumberOfSales_y  prediction_label
# 3443                0             282                0          0.000000
# 3444                0             255             3841       3740.435001
# 3445                0             281             3449       3612.078279
# 3446                0              94             3635       3560.561395
# 3447                0             115             3723       3667.208882
# ...               ...             ...              ...               ...
# 4914             0,51             224             4379       4415.064818
# 4915                0             223                0          0.000000
# 4916             1,02             194             5074       3992.497560
# 4917             1,02             215             5148       4206.276421
# 4918             0,25             211             4917       4275.767515
#
# [1476 rows x 38 columns]

# %%
final_model = finalize_model(Model)
final_model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['StoreID', 'IsHoliday', 'IsOpen',
#                                              'HasPromotions',
#                                              'NearestCompetitor', 'Region',
#                                              'NumberOfCustomers',
#                                              'NumberOfSales_x',
#                                              'Region_AreaKM2', 'Region_GDP',
#                                              'Region_PopulationK', 'CloudCover',
#                                              'Max_Dew_PointC',
#                                              'Max_Gust_SpeedKm_h',
#                                              'Max_Humidity',
#                                              'Max_Sea_Level_PressurehP...
#                                     transformer=RemoveMulticollinearity(threshold=0.9))),
#                 ('feature_selection',
#                  TransformerWrapper(exclude=[],
#                                     transformer=SelectKBest(k=7,
#                                                             score_func=<function f_regression at 0x0000024411AA5FC0>))),
#                 ('actual_estimator',
#                  ExtraTreesRegressor(max_depth=11, max_features='log2',
#                                      min_impurity_decrease=0.0001,
#                                      min_samples_leaf=3, min_samples_split=7,
#                                      n_estimators=30, n_jobs=-1,
#                                      random_state=42))])

# %%
get_config('y_test')
# Out:
# 3443       0
# 3444    3841
# 3445    3449
# 3446    3635
# 3447    3723
#         ...
# 4914    4379
# 4915       0
# 4916    5074
# 4917    5148
# 4918    4917
# Name: NumberOfSales_y, Length: 1476, dtype: int32

# %%
predict_model(final_model,data=get_config('y_test'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6468\3031433149.py in ?()
# ----> 1 predict_model(final_model,data=get_config('y_test'))
#
# c:\Users\Luzia\anaconda3\envs\py3.10.6\lib\site-packages\pycaret\regression\functional.py in ?(estimator, data, round, verbose)
#    1891     experiment = _CURRENT_EXPERIMENT
#    1892     if experiment is None:
#    1893         experiment = _EXPERIMENT_CLASS()
#    1894
# -> 1895     return experiment.predict_model(
#    1896         estimator=estimator,
#    1897         data=data,
#    1898         round=round,
#
# c:\Users\Luzia\anaconda3\envs\py3.10.6\lib\site-packages\pycaret\regression\oop.py in ?(self, estimator, data, round, verbose)
#    2184
#    2185
#    2186         """
#    2187
# -> 2188         return super().predict_model(
#    2189             estimator=estimator,
#    2190             data=data,
#    2191             probability_threshold=None,
#
# c:\Users\Luzia\anaconda3\envs\py3.10.6\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in ?(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4932             X_test_, y_test_ = self.X_test_transformed, self.y_test_transformed
#    4933             X_test_untransformed = self.X_test[self.X_test.index.isin(X_test_.index)]
#    4934             y_test_untransformed = self.y_test[self.y_test.index.isin(y_test_.index)]
#    4935         else:
# -> 4936             if y_name in data.columns:
#    4937                 data = self._set_index(self._prepare_dataset(data, y_name))
#    4938                 target = data[y_name]
#    4939                 data = data.drop(y_name, axis=1)
#
# c:\Users\Luzia\anaconda3\envs\py3.10.6\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
# Define a function that decomposes the date into day, month, year, and other features
def decompose_date(df, date_col,format_str="%d/%m/%Y"):
  # Convert the date column to datetime type
  df[date_col] = pd.to_datetime(df[date_col], format=format_str)
  # Extract the day, month, and year from the date column
  df['day'] = df[date_col].dt.day
  df['month'] = df[date_col].dt.month
  df['year'] = df[date_col].dt.year
  # Extract the day of week, week of year, and quarter from the date column
  df['dayofweek'] = df[date_col].dt.dayofweek
  df['weekofyear'] = df[date_col].dt.isocalendar().week
  df['quarter'] = df[date_col].dt.quarter
  # Extract the season from the month column (using meteorological seasons for Italy)
  seasons = {(12, 1, 2): 'winter', (3, 4, 5): 'spring', (6, 7, 8): 'summer', (9, 10, 11): 'autumn'}
  df['season'] = df['month'].apply(lambda x: next(v for k, v in seasons.items() if x in k))
  # Drop the original date column
  #df = df.drop(date_col, axis=1)
  # Return the transformed data frame
  return df

# Call the function with the date column name
df = decompose_date(df, "Date")

# Print the first 10 rows of the transformed data
print(df.head(3))

# %% [markdown]
# ##**Auto-Imputation:**

# %%
import pandas as pd

# %%
corr = df2[["StoreID", "NumberOfSales"]].corr().iloc[0, 1]
col = "StoreID"
target = "NumberOfSales"
print('Correlation between'+col+' and '+target+' is '+ str(corr))
# Out:
# Correlation betweenStoreID and NumberOfSales is 0.029624658752800175

# %%
import seaborn as sns

# %%
sns.pairplot(df2[df2.columns])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 40 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(df2[df2.columns], aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
g.map_diag(sns.histplot, kde_kws={'color': 'black'})
g.map_upper(corrdot)

plt.show()

# %%
print(df2["Events"].dtype)

# %%
  from sklearn.impute import SimpleImputer
  import numpy as np
  def impute_column(df, col, target):
    # Check if the column has any missing values
    if df[col].isnull().any():
      # Get the percentage of missing values in the column
      percent = df[col].isnull().mean() * 100
      # If the percentage is more than 50, drop the column and return the dataframe
      if percent > 50:
        df.drop(col, axis=1, inplace=True)
        return pd.DataFrame(data=None)
      # Otherwise, proceed with the imputation process
      else:
        # Get the data type of the column
        dtype = df[col].dtype
        # If the column is numeric
        if dtype in ["int", "float"]:
          # Check if there is a strong correlation between the column and the target variable
          corr = df[[col, target]].corr().iloc[0, 1]
          print('Correlation between '+col+' and '+target+' is '+ str(corr))
          # If the correlation coefficient is above 0.5 or below -0.5, use random forest imputation
          if abs(corr) > 0.5:
            # Import the RandomForestRegressor or RandomForestClassifier class from scikit-learn
            from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
            imp_model = RandomForestRegressor()
            print("Correlation is greater than 0.5 -> Using Random Forest regressor")
            # Fit the model on the rows that have no missing values in the column, using all other columns as predictors
            imp_model.fit(df.dropna()[df.columns.drop(col)], df.dropna()[col])
            # Predict the missing values in the column using the fitted model and the other columns as inputs
            df.loc[df[col].isnull(), col] = imp_model.predict(df[df[col].isnull()][df.columns.drop(col)])
          else:
            # Get the distribution of the column
            skewness = df[col].skew()
            # If the column is normally distributed, use mean imputation
            if abs(skewness) < 0.5:
              print('Absolute Skewness in column '+col+' is '+ str(abs(skewness)) + ' < 0.5, imputing the mean')
              imp_mean = SimpleImputer(missing_values=np.nan, strategy="mean")
              df[col] = imp_mean.fit_transform(df[[col]])
            # If the column is skewed, use median imputation
            else:
              print('Absolute Skewness in column '+col+' is ' + str(abs(skewness)) + ' > 0.5, imputing the median')
              imp_median = SimpleImputer(missing_values=np.nan, strategy="median")
              df[col] = imp_median.fit_transform(df[[col]])

        # If the column is categorical
        elif dtype == "object" or dtype == "category":
          # Get the frequency of each category
          mode = df[col].mode()[0]
          count = df[col].value_counts()[mode]
          # If there is a clear mode, use mode imputation
          if count > df.shape[0] * 0.5:
            print("There is a clear mode in column: '+col+' -> Imputing the most frequent")
            imp_mode = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
            df[col] = imp_mode.fit_transform(df[[col]])
          # If there is no clear mode, use constant value imputation
          else:
            print('There is no clear mode in the Categorical column: '+col+' -> imputing "Unknown"')
            imp_constant = SimpleImputer(missing_values=np.nan, strategy="constant", fill_value="Unknown")
            df[col] = imp_constant.fit_transform(df[[col]])
        # If the column is neither numeric nor categorical, raise an error
        else:
          raise ValueError(f"Unsupported data type: {dtype}")
    else:
      print(col + " has no missing values.")
    return df[col]

Target_Col="NumberOfSales"
  # Loop over all columns of df and impute values
  for col in df2.columns.drop(Target_Col):
    # Call the impute_column function with each column name
    df_column = impute_column(df2, col, Target_Col)
    if not df_column.empty:
      df2[col] = df_column
    else:
      print(col+ " has over 50% missing velues column DROPPED")
